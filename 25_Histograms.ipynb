# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Data_Viz/blob/main/25_Histograms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Histograms

# %% [markdown]
# Next we look at many quantititative variables.  Looking at the histogram allows us to get an idea of the shape of the distribution.

# %%
import pandas as pa

df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/iris.csv')

# %%
df.SepalLength.plot.hist()

# %% [markdown]
# Remember to look at multiple bin widths when doing a histogram it may make a difference in the display of your data!  The default is 10 which is not bad here.

# %%
df.SepalLength.plot.hist(bins = 100)

# %% [markdown]
# 100 was too many and 5 too few.

# %%
df.SepalLength.plot.hist(bins = 5)

# %% [markdown]
# 25 bins gave a little more clarity to how the data was distributed.

# %%
df.SepalLength.plot.hist(bins = 25)

# %%
df['SepalLength'].hist(by = df['Class'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff218978510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff2185fc5d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff2185b19d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff218567ed0>]],
#       dtype=object)

# %% [markdown]
# One of the issues in the above graph is that the axis do not match.  Can you fix that?
#
# Below I put them all together on the same axis.  The `alpha` value makes them transparent.

# %%
df.groupby('Class').SepalLength.plot.hist(alpha = .7)
# Out:
# Class
# Iris-setosa        AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-versicolor    AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-virginica     AxesSubplot(0.125,0.125;0.775x0.755)
# Name: SepalLength, dtype: object

# %%
df.groupby('Class').plot.hist(alpha = .7)
# Out:
# Class
# Iris-setosa        AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-versicolor    AxesSubplot(0.125,0.125;0.775x0.755)
# Iris-virginica     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff219059810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff219e14a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff21902c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff218fe2b50>]],
#       dtype=object)
