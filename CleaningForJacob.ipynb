# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Data_Viz/blob/main/CleaningForJacob.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scrapping NFL Player Data

# %% [markdown]
# I found this site with the nfl players by position with the data we were interested in.  Here is an attempt to scrape it!

# %%
import requests
import pandas as pa
from bs4 import BeautifulSoup


r = requests.get('https://newsday.sportsdirectinc.com/football/nfl-players.aspx?page=/data/nfl/players/A_players.html')
html_contents = r.text
html_soup = BeautifulSoup(html_contents,"lxml")

# %%
tables = html_soup.find_all('table')
len(tables)
# Out:
# 3

# %%
df = pa.read_html(str(tables))[2]
df.columns = df.iloc[0,:]
df = df.iloc[1:,:]
df
# Out:
# 0               Player Pos Team Num Height   Weight       DOB
# 1   Abanikanda, Israel  RB  NYJ  25  5'11"  215 lbs   10/5/02
# 2      Abdullah, Ameer  RB   LV  22   5'9"  203 lbs   6/13/93
# 3      Abdullah, Yasir  LB  JAC  56   6'1"  234 lbs   4/12/00
# 4     Abernathy, Micah   S  ATL  29   6'0"  196 lbs   2/10/97
# 5     Abram, Johnathan   S   NO  24   6'0"  205 lbs  10/25/96
# ..                 ...  ..  ...  ..    ...      ...       ...
# 88       Avery, Genard  DE  IND   -   6'0"  250 lbs   4/26/95
# 89          Avery, Tre  CB  TEN  23  5'11"  181 lbs   2/26/97
# 90        Avila, Steve  OL  LAR  73   6'3"  332 lbs  10/16/99
# 91     Awosika, Kayode   G  DET  74   6'3"  315 lbs  10/27/98
# 92     Awuzie, Chidobe  CB  TEN  22   6'0"  202 lbs   5/24/95
#
# [92 rows x 7 columns]

# %%
import string
let = string.ascii_uppercase
let[1:]
# Out:
# 'BCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
for i in let[1:]:
  r = requests.get('https://newsday.sportsdirectinc.com/football/nfl-players.aspx?page=/data/nfl/players/' + i +'_players.html')
  html_contents = r.text
  html_soup = BeautifulSoup(html_contents,"lxml")
  tables = html_soup.find_all('table')
  dftemp = pa.read_html(str(tables))[2]
  dftemp.columns = dftemp.iloc[0,:]
  dftemp = dftemp.iloc[1:,:]
  df = pa.concat([df,dftemp])

df
# Out:
# 0               Player Pos Team Num Height   Weight       DOB
# 1   Abanikanda, Israel  RB  NYJ  25  5'11"  215 lbs   10/5/02
# 2      Abdullah, Ameer  RB   LV  22   5'9"  203 lbs   6/13/93
# 3      Abdullah, Yasir  LB  JAC  56   6'1"  234 lbs   4/12/00
# 4     Abernathy, Micah   S  ATL  29   6'0"  196 lbs   2/10/97
# 5     Abram, Johnathan   S   NO  24   6'0"  205 lbs  10/25/96
# ..                 ...  ..  ...  ..    ...      ...       ...
# 5       Zeitler, Kevin   G  DET   -   6'4"  340 lbs    3/8/90
# 6          Zentner, Ty   P  TEN  13   6'2"  200 lbs    6/7/98
# 7       Zierer, Kilian  OT  HOU  66   6'7"  312 lbs   2/24/98
# 8       Zuerlein, Greg   K  NYJ   9   6'0"  187 lbs  12/27/87
# 9       Zylstra, Shane  TE  DET  84   6'4"  240 lbs  11/16/96
#
# [2221 rows x 7 columns]

# %%
df.to_csv("players.csv", index = False)
