# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Data_Viz/blob/main/11_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Twitter a Social Media Scrape

# %% [markdown]
# ## Authorizing a Twitter Account

# %% [markdown]
# First you'll need the [twitter package](https://pypi.org/project/twitter/)!  It is not automatically loaded into colab.

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading twitter-1.19.3-py2.py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 2.7 MB/s
# Installing collected packages: twitter
# Successfully installed twitter-1.19.3

# %% [markdown]
# Next you'll need the authentication codes for a twitter api.  You can use your own twitter account and follow the directions [here](https://developer.twitter.com/en/docs/authentication/oauth-1-0a/api-key-and-secret).
#
# For class I have shared some authentication keys.  In order to keep these secret (GitHub won't let us post secrets to their website!) I have created a file called `config.py`.  I upload this into the environment (file structure) of colab and I reference it like a package.  This means only if you have this file can you get to it but I can share my code with everyone still.

# %%
import twitter
import config

CONSUMER_KEY = config.CONSUMER_KEY
CONSUMER_SECRET = config.CONSUMER_SECRET
OAUTH_TOKEN = config.OAUTH_TOKEN
OAUTH_TOKEN_SECRET = config.OAUTH_TOKEN_SECRET
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

mathcs_twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# ## Posting to Social Media

# %%
status = "Having fun in Data Processing and Vizualization class!  Posting to twitter has never been easier!"

mathcs_twitter_api.statuses.update(
    status=status)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Feb 01 18:20:49 +0000 2022',
#  'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1488578097469345794,
#  'id_str': '1488578097469345794',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://ecok.edu/academics/colleges-and-schools/college-health-and-sciences/department-mathematics-and-computer" rel="nofollow">Starlas Data Project</a>',
#  'text': 'Having fun in Data Processing and Vizualization class!  Posting to twitter has never been easier!',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Tue Sep 04 18:38:49 +0000 2018',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': '',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'bit.ly/2NfSiTh',
#       'expanded_url': 'https://bit.ly/2NfSiTh',
#       'indices': [0, 23],
#       'url': 'https://t.co/PugruxKlLL'}]}},
#   'favourites_count': 0,
#   'follow_request_sent': False,
#   'followers_count': 10,
#   'following': False,
#   'friends_count': 32,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 1037047347405045760,
#   'id_str': '1037047347405045760',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': None,
#   'listed_count': 0,
#   'location': 'Ada, OK',
#   'name': 'ECU_Math/CS',
#   'notifications': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1037047347405045760/1536096251',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1037089960514310144/Kk2ypzpr_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1037089960514310144/Kk2ypzpr_normal.jpg',
#   'profile_link_color': 'FF5400',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'cs_ecu',
#   'statuses_count': 27,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/PugruxKlLL',
#   'utc_offset': None,
#   'verified': False,
#   'withheld_in_countries': []}}

# %% [markdown]
# The above shows the tweet was made to my account.  You can even go find it!  Think about how great you life could be if you automate all your interactions with socials too!

# %% [markdown]
# ## What is the Twitterverse Discussing?

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = nurfnick_twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = nurfnick_twitter_api.trends.place(_id=US_WOE_ID)

for i in range(10):
    print(world_trends[0]['trends'][i]['query'])
# Out:
# Rihanna
# Bungie
# Sony
# %23PSGOGCN
# Destiny
# %23DebateCYLrtve
# %23survivor2022allstar
# Riri
# Messi
# Arsenal

# %%
for i in range(3):
    print(us_trends[0]['trends'][i]['query'])
# Out:
# Rihanna
# Bungie
# Sony

# %% [markdown]
# Here is a nicer display of the data using `json` package.  JSON is anotherway to store data and is utilized in many no-sql databases.

# %%
import json

print(json.dumps(world_trends, indent=1))
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "Rihanna",
#     "url": "http://twitter.com/search?q=Rihanna",
#     "promoted_content": null,
#     "query": "Rihanna",
#     "tweet_volume": 1011572
#    },
#    {
#     "name": "Bungie",
#     "url": "http://twitter.com/search?q=Bungie",
#     "promoted_content": null,
#     "query": "Bungie",
#     "tweet_volume": 134417
#    },
#    {
#     "name": "Sony",
#     "url": "http://twitter.com/search?q=Sony",
#     "promoted_content": null,
#     "query": "Sony",
#     "tweet_volume": 140544
#    },
#    {
#     "name": "#PSGOGCN",
#     "url": "http://twitter.com/search?q=%23PSGOGCN",
#     "promoted_content": null,
#     "query": "%23PSGOGCN",
#     "tweet_volume": 16053
#    },
#    {
#     "name": "Destiny",
#     "url": "http://twitter.com/search?q=Destiny",
#     "promoted_content": null,
#     "query": "Destiny",
#     "tweet_volume": 104446
#    },
#    {
#     "name": "#DebateCYLrtve",
#     "url": "http://twitter.com/search?q=%23DebateCYLrtve",
#     "promoted_content": null,
#     "query": "%23DebateCYLrtve",
#     "tweet_volume": 11878
#    },
#    {
#     "name": "#survivor2022allstar",
#     "url": "http://twitter.com/search?q=%23survivor2022allstar",
#     "promoted_content": null,
#     "query": "%23survivor2022allstar",
#     "tweet_volume": 37545
#    },
#    {
#     "name": "Riri",
#     "url": "http://twitter.com/search?q=Riri",
#     "promoted_content": null,
#     "query": "Riri",
#     "tweet_volume": 136163
#    },
#    {
#     "name": "Arsenal",
#     "url": "http://twitter.com/search?q=Arsenal",
#     "promoted_content": null,
#     "query": "Arsenal",
#     "tweet_volume": 218363
#    },
#    {
#     "name": "#\u0627\u0644\u0633\u062a\u0631_\u0641\u0637\u0631\u0647_\u0648\u0627\u0644\u062d\u062c\u0627\u0628_\u0641\u0631\u064a\u0636\u0647",
#     "url": "http://twitter.com/search?q=%23%D8%A7%D9%84%D8%B3%D8%AA%D8%B1_%D9%81%D8%B7%D8%B1%D9%87_%D9%88%D8%A7%D9%84%D8%AD%D8%AC%D8%A7%D8%A8_%D9%81%D8%B1%D9%8A%D8%B6%D9%87",
#     "promoted_content": null,
#     "query": "%23%D8%A7%D9%84%D8%B3%D8%AA%D8%B1_%D9%81%D8%B7%D8%B1%D9%87_%D9%88%D8%A7%D9%84%D8%AD%D8%AC%D8%A7%D8%A8_%D9%81%D8%B1%D9%8A%D8%B6%D9%87",
#     "tweet_volume": 40763
#    },
#    {
#     "name": "Messi",
#     "url": "http://twitter.com/search?q=Messi",
#     "promoted_content": null,
#     "query": "Messi",
#     "tweet_volume": 131152
#    },
#    {
#     "name": "Nadine Dorries",
#     "url": "http://twitter.com/search?q=%22Nadine+Dorries%22",
#     "promoted_content": null,
#     "query": "%22Nadine+Dorries%22",
#     "tweet_volume": 24720
#    },
#    {
#     "name": "PlayStation",
#     "url": "http://twitter.com/search?q=PlayStation",
#     "promoted_content": null,
#     "query": "PlayStation",
#     "tweet_volume": 203266
#    },
#    {
#     "name": "#\u0645\u0633\u0627\u062d\u0647_\u062e\u0627\u0644\u062f_\u0627\u0644\u0628\u0644\u0637\u0627\u0646",
#     "url": "http://twitter.com/search?q=%23%D9%85%D8%B3%D8%A7%D8%AD%D9%87_%D8%AE%D8%A7%D9%84%D8%AF_%D8%A7%D9%84%D8%A8%D9%84%D8%B7%D8%A7%D9%86",
#     "promoted_content": null,
#     "query": "%23%D9%85%D8%B3%D8%A7%D8%AD%D9%87_%D8%AE%D8%A7%D9%84%D8%AF_%D8%A7%D9%84%D8%A8%D9%84%D8%B7%D8%A7%D9%86",
#     "tweet_volume": 60507
#    },
#    {
#     "name": "Johnson",
#     "url": "http://twitter.com/search?q=Johnson",
#     "promoted_content": null,
#     "query": "Johnson",
#     "tweet_volume": 489216
#    },
#    {
#     "name": "Auba",
#     "url": "http://twitter.com/search?q=Auba",
#     "promoted_content": null,
#     "query": "Auba",
#     "tweet_volume": 63906
#    },
#    {
#     "name": "Activision",
#     "url": "http://twitter.com/search?q=Activision",
#     "promoted_content": null,
#     "query": "Activision",
#     "tweet_volume": 28058
#    },
#    {
#     "name": "Drake",
#     "url": "http://twitter.com/search?q=Drake",
#     "promoted_content": null,
#     "query": "Drake",
#     "tweet_volume": 167494
#    },
#    {
#     "name": "Halo",
#     "url": "http://twitter.com/search?q=Halo",
#     "promoted_content": null,
#     "query": "Halo",
#     "tweet_volume": 185639
#    },
#    {
#     "name": "Verratti",
#     "url": "http://twitter.com/search?q=Verratti",
#     "promoted_content": null,
#     "query": "Verratti",
#     "tweet_volume": null
#    },
#    {
#     "name": "Whoopi",
#     "url": "http://twitter.com/search?q=Whoopi",
#     "promoted_content": null,
#     "query": "Whoopi",
#     "tweet_volume": 15481
#    },
#    {
#     "name": "ASAP Rocky",
#     "url": "http://twitter.com/search?q=%22ASAP+Rocky%22",
#     "promoted_content": null,
#     "query": "%22ASAP+Rocky%22",
#     "tweet_volume": 111178
#    },
#    {
#     "name": "Mirtha V\u00e1squez",
#     "url": "http://twitter.com/search?q=%22Mirtha+V%C3%A1squez%22",
#     "promoted_content": null,
#     "query": "%22Mirtha+V%C3%A1squez%22",
#     "tweet_volume": 11529
#    },
#    {
#     "name": "Delia",
#     "url": "http://twitter.com/search?q=Delia",
#     "promoted_content": null,
#     "query": "Delia",
#     "tweet_volume": 26737
#    },
#    {
#     "name": "Arteta",
#     "url": "http://twitter.com/search?q=Arteta",
#     "promoted_content": null,
#     "query": "Arteta",
#     "tweet_volume": 33225
#    },
#    {
#     "name": "Icardi",
#     "url": "http://twitter.com/search?q=Icardi",
#     "promoted_content": null,
#     "query": "Icardi",
#     "tweet_volume": 18462
#    },
#    {
#     "name": "BuSu\u00e7a OrtakOlma",
#     "url": "http://twitter.com/search?q=%22BuSu%C3%A7a+OrtakOlma%22",
#     "promoted_content": null,
#     "query": "%22BuSu%C3%A7a+OrtakOlma%22",
#     "tweet_volume": 59454
#    },
#    {
#     "name": "\u7d2b\u8000\u304f\u3093CM",
#     "url": "http://twitter.com/search?q=%E7%B4%AB%E8%80%80%E3%81%8F%E3%82%93CM",
#     "promoted_content": null,
#     "query": "%E7%B4%AB%E8%80%80%E3%81%8F%E3%82%93CM",
#     "tweet_volume": null
#    },
#    {
#     "name": "Evrim",
#     "url": "http://twitter.com/search?q=Evrim",
#     "promoted_content": null,
#     "query": "Evrim",
#     "tweet_volume": 22739
#    },
#    {
#     "name": "Aaron Ramsey",
#     "url": "http://twitter.com/search?q=%22Aaron+Ramsey%22",
#     "promoted_content": null,
#     "query": "%22Aaron+Ramsey%22",
#     "tweet_volume": 47197
#    },
#    {
#     "name": "Starmer",
#     "url": "http://twitter.com/search?q=Starmer",
#     "promoted_content": null,
#     "query": "Starmer",
#     "tweet_volume": 162942
#    },
#    {
#     "name": "Roberto Toledo",
#     "url": "http://twitter.com/search?q=%22Roberto+Toledo%22",
#     "promoted_content": null,
#     "query": "%22Roberto+Toledo%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ian Blackford",
#     "url": "http://twitter.com/search?q=%22Ian+Blackford%22",
#     "promoted_content": null,
#     "query": "%22Ian+Blackford%22",
#     "tweet_volume": 62053
#    },
#    {
#     "name": "Rangers",
#     "url": "http://twitter.com/search?q=Rangers",
#     "promoted_content": null,
#     "query": "Rangers",
#     "tweet_volume": 70845
#    },
#    {
#     "name": "\u015eubat",
#     "url": "http://twitter.com/search?q=%C5%9Eubat",
#     "promoted_content": null,
#     "query": "%C5%9Eubat",
#     "tweet_volume": 81353
#    },
#    {
#     "name": "Dembele",
#     "url": "http://twitter.com/search?q=Dembele",
#     "promoted_content": null,
#     "query": "Dembele",
#     "tweet_volume": 121638
#    },
#    {
#     "name": "Lorca",
#     "url": "http://twitter.com/search?q=Lorca",
#     "promoted_content": null,
#     "query": "Lorca",
#     "tweet_volume": 79206
#    },
#    {
#     "name": "Inesita",
#     "url": "http://twitter.com/search?q=Inesita",
#     "promoted_content": null,
#     "query": "Inesita",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bermejo",
#     "url": "http://twitter.com/search?q=Bermejo",
#     "promoted_content": null,
#     "query": "Bermejo",
#     "tweet_volume": null
#    },
#    {
#     "name": "Parliament",
#     "url": "http://twitter.com/search?q=Parliament",
#     "promoted_content": null,
#     "query": "Parliament",
#     "tweet_volume": 240122
#    },
#    {
#     "name": "Happy Lunar New Year",
#     "url": "http://twitter.com/search?q=%22Happy+Lunar+New+Year%22",
#     "promoted_content": null,
#     "query": "%22Happy+Lunar+New+Year%22",
#     "tweet_volume": 211455
#    },
#    {
#     "name": "Ma\u00f1ueco",
#     "url": "http://twitter.com/search?q=Ma%C3%B1ueco",
#     "promoted_content": null,
#     "query": "Ma%C3%B1ueco",
#     "tweet_volume": 18291
#    },
#    {
#     "name": "Barca",
#     "url": "http://twitter.com/search?q=Barca",
#     "promoted_content": null,
#     "query": "Barca",
#     "tweet_volume": 118471
#    },
#    {
#     "name": "Trudeau",
#     "url": "http://twitter.com/search?q=Trudeau",
#     "promoted_content": null,
#     "query": "Trudeau",
#     "tweet_volume": 496604
#    },
#    {
#     "name": "Dora Cadavid",
#     "url": "http://twitter.com/search?q=%22Dora+Cadavid%22",
#     "promoted_content": null,
#     "query": "%22Dora+Cadavid%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Danilo",
#     "url": "http://twitter.com/search?q=Danilo",
#     "promoted_content": null,
#     "query": "Danilo",
#     "tweet_volume": 10715
#    },
#    {
#     "name": "Bello Monte",
#     "url": "http://twitter.com/search?q=%22Bello+Monte%22",
#     "promoted_content": null,
#     "query": "%22Bello+Monte%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Nazis",
#     "url": "http://twitter.com/search?q=Nazis",
#     "promoted_content": null,
#     "query": "Nazis",
#     "tweet_volume": 177867
#    },
#    {
#     "name": "AMAZON NO PROCON",
#     "url": "http://twitter.com/search?q=%22AMAZON+NO+PROCON%22",
#     "promoted_content": null,
#     "query": "%22AMAZON+NO+PROCON%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Lapadula",
#     "url": "http://twitter.com/search?q=Lapadula",
#     "promoted_content": null,
#     "query": "Lapadula",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2022-01-31T22:09:10Z",
#   "created_at": "2022-01-24T07:54:29Z",
#   "locations": [
#    {
#     "name": "Worldwide",
#     "woeid": 1
#    }
#   ]
#  }
# ]
# [
#  {
#   "trends": [
#    {
#     "name": "Rihanna",
#     "url": "http://twitter.com/search?q=Rihanna",
#     "promoted_content": null,
#     "query": "Rihanna",
#     "tweet_volume": 1011572
#    },
#    {
#     "name": "Bungie",
#     "url": "http://twitter.com/search?q=Bungie",
#     "promoted_content": null,
#     "query": "Bungie",
#     "tweet_volume": 134417
#    },
#    {
#     "name": "Sony",
#     "url": "http://twitter.com/search?q=Sony",
#     "promoted_content": null,
#     "query": "Sony",
#     "tweet_volume": 140544
#    },
#    {
#     "name": "Destiny",
#     "url": "http://twitter.com/search?q=Destiny",
#     "promoted_content": null,
#     "query": "Destiny",
#     "tweet_volume": 104446
#    },
#    {
#     "name": "Whoopi",
#     "url": "http://twitter.com/search?q=Whoopi",
#     "promoted_content": null,
#     "query": "Whoopi",
#     "tweet_volume": 15481
#    },
#    {
#     "name": "PlayStation",
#     "url": "http://twitter.com/search?q=PlayStation",
#     "promoted_content": null,
#     "query": "PlayStation",
#     "tweet_volume": 203266
#    },
#    {
#     "name": "Activision",
#     "url": "http://twitter.com/search?q=Activision",
#     "promoted_content": null,
#     "query": "Activision",
#     "tweet_volume": 28058
#    },
#    {
#     "name": "Riri",
#     "url": "http://twitter.com/search?q=Riri",
#     "promoted_content": null,
#     "query": "Riri",
#     "tweet_volume": 136163
#    },
#    {
#     "name": "#HonkHonk",
#     "url": "http://twitter.com/search?q=%23HonkHonk",
#     "promoted_content": null,
#     "query": "%23HonkHonk",
#     "tweet_volume": 47564
#    },
#    {
#     "name": "Drake",
#     "url": "http://twitter.com/search?q=Drake",
#     "promoted_content": null,
#     "query": "Drake",
#     "tweet_volume": 167494
#    },
#    {
#     "name": "#YIAYdevil",
#     "url": "http://twitter.com/search?q=%23YIAYdevil",
#     "promoted_content": null,
#     "query": "%23YIAYdevil",
#     "tweet_volume": null
#    },
#    {
#     "name": "Rocky",
#     "url": "http://twitter.com/search?q=Rocky",
#     "promoted_content": null,
#     "query": "Rocky",
#     "tweet_volume": 303841
#    },
#    {
#     "name": "Musiq",
#     "url": "http://twitter.com/search?q=Musiq",
#     "promoted_content": null,
#     "query": "Musiq",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PMSThankYewSeatGeek",
#     "url": "http://twitter.com/search?q=%23PMSThankYewSeatGeek",
#     "promoted_content": null,
#     "query": "%23PMSThankYewSeatGeek",
#     "tweet_volume": null
#    },
#    {
#     "name": "Anthony Hamilton",
#     "url": "http://twitter.com/search?q=%22Anthony+Hamilton%22",
#     "promoted_content": null,
#     "query": "%22Anthony+Hamilton%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "New York Times",
#     "url": "http://twitter.com/search?q=%22New+York+Times%22",
#     "promoted_content": null,
#     "query": "%22New+York+Times%22",
#     "tweet_volume": 21095
#    },
#    {
#     "name": "Halo",
#     "url": "http://twitter.com/search?q=Halo",
#     "promoted_content": null,
#     "query": "Halo",
#     "tweet_volume": 185639
#    },
#    {
#     "name": "Nazis",
#     "url": "http://twitter.com/search?q=Nazis",
#     "promoted_content": null,
#     "query": "Nazis",
#     "tweet_volume": 177867
#    },
#    {
#     "name": "Nick Cannon",
#     "url": "http://twitter.com/search?q=%22Nick+Cannon%22",
#     "promoted_content": null,
#     "query": "%22Nick+Cannon%22",
#     "tweet_volume": 37007
#    },
#    {
#     "name": "Nintendo",
#     "url": "http://twitter.com/search?q=Nintendo",
#     "promoted_content": null,
#     "query": "Nintendo",
#     "tweet_volume": 152970
#    },
#    {
#     "name": "#FromTheVault",
#     "url": "http://twitter.com/search?q=%23FromTheVault",
#     "promoted_content": null,
#     "query": "%23FromTheVault",
#     "tweet_volume": null
#    },
#    {
#     "name": "Happy Lunar New Year",
#     "url": "http://twitter.com/search?q=%22Happy+Lunar+New+Year%22",
#     "promoted_content": null,
#     "query": "%22Happy+Lunar+New+Year%22",
#     "tweet_volume": 211455
#    },
#    {
#     "name": "Josh Wardle",
#     "url": "http://twitter.com/search?q=%22Josh+Wardle%22",
#     "promoted_content": null,
#     "query": "%22Josh+Wardle%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MondayMotivation",
#     "url": "http://twitter.com/search?q=%23MondayMotivation",
#     "promoted_content": null,
#     "query": "%23MondayMotivation",
#     "tweet_volume": 101283
#    },
#    {
#     "name": "Vaseline",
#     "url": "http://twitter.com/search?q=Vaseline",
#     "promoted_content": null,
#     "query": "Vaseline",
#     "tweet_volume": null
#    },
#    {
#     "name": "RIP Wordle",
#     "url": "http://twitter.com/search?q=%22RIP+Wordle%22",
#     "promoted_content": null,
#     "query": "%22RIP+Wordle%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Auba",
#     "url": "http://twitter.com/search?q=Auba",
#     "promoted_content": null,
#     "query": "Auba",
#     "tweet_volume": 63906
#    },
#    {
#     "name": "Leatherface",
#     "url": "http://twitter.com/search?q=Leatherface",
#     "promoted_content": null,
#     "query": "Leatherface",
#     "tweet_volume": 10392
#    },
#    {
#     "name": "Arsenal",
#     "url": "http://twitter.com/search?q=Arsenal",
#     "promoted_content": null,
#     "query": "Arsenal",
#     "tweet_volume": 218363
#    },
#    {
#     "name": "Trudeau",
#     "url": "http://twitter.com/search?q=Trudeau",
#     "promoted_content": null,
#     "query": "Trudeau",
#     "tweet_volume": 496604
#    },
#    {
#     "name": "Davey Richards",
#     "url": "http://twitter.com/search?q=%22Davey+Richards%22",
#     "promoted_content": null,
#     "query": "%22Davey+Richards%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The View",
#     "url": "http://twitter.com/search?q=%22The+View%22",
#     "promoted_content": null,
#     "query": "%22The+View%22",
#     "tweet_volume": 146193
#    },
#    {
#     "name": "Rhianna",
#     "url": "http://twitter.com/search?q=Rhianna",
#     "promoted_content": null,
#     "query": "Rhianna",
#     "tweet_volume": null
#    },
#    {
#     "name": "Texas Chainsaw Massacre",
#     "url": "http://twitter.com/search?q=%22Texas+Chainsaw+Massacre%22",
#     "promoted_content": null,
#     "query": "%22Texas+Chainsaw+Massacre%22",
#     "tweet_volume": 10794
#    },
#    {
#     "name": "Newsom",
#     "url": "http://twitter.com/search?q=Newsom",
#     "promoted_content": null,
#     "query": "Newsom",
#     "tweet_volume": 42458
#    },
#    {
#     "name": "Ben Stiller",
#     "url": "http://twitter.com/search?q=%22Ben+Stiller%22",
#     "promoted_content": null,
#     "query": "%22Ben+Stiller%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Black History Month",
#     "url": "http://twitter.com/search?q=%22Black+History+Month%22",
#     "promoted_content": null,
#     "query": "%22Black+History+Month%22",
#     "tweet_volume": 20444
#    },
#    {
#     "name": "Voltaire",
#     "url": "http://twitter.com/search?q=Voltaire",
#     "promoted_content": null,
#     "query": "Voltaire",
#     "tweet_volume": 17281
#    },
#    {
#     "name": "Ahmaud Arbery",
#     "url": "http://twitter.com/search?q=%22Ahmaud+Arbery%22",
#     "promoted_content": null,
#     "query": "%22Ahmaud+Arbery%22",
#     "tweet_volume": 15911
#    },
#    {
#     "name": "Notifications",
#     "url": "http://twitter.com/search?q=Notifications",
#     "promoted_content": null,
#     "query": "Notifications",
#     "tweet_volume": 114938
#    },
#    {
#     "name": "Halsey",
#     "url": "http://twitter.com/search?q=Halsey",
#     "promoted_content": null,
#     "query": "Halsey",
#     "tweet_volume": 21965
#    },
#    {
#     "name": "Bryn Mawr",
#     "url": "http://twitter.com/search?q=%22Bryn+Mawr%22",
#     "promoted_content": null,
#     "query": "%22Bryn+Mawr%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Travis McMichael",
#     "url": "http://twitter.com/search?q=%22Travis+McMichael%22",
#     "promoted_content": null,
#     "query": "%22Travis+McMichael%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "HBCUs",
#     "url": "http://twitter.com/search?q=HBCUs",
#     "promoted_content": null,
#     "query": "HBCUs",
#     "tweet_volume": 17441
#    },
#    {
#     "name": "Kid Icarus",
#     "url": "http://twitter.com/search?q=%22Kid+Icarus%22",
#     "promoted_content": null,
#     "query": "%22Kid+Icarus%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Halloween 2018",
#     "url": "http://twitter.com/search?q=%22Halloween+2018%22",
#     "promoted_content": null,
#     "query": "%22Halloween+2018%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Trusty",
#     "url": "http://twitter.com/search?q=Trusty",
#     "promoted_content": null,
#     "query": "Trusty",
#     "tweet_volume": null
#    },
#    {
#     "name": "Wordle 226 X",
#     "url": "http://twitter.com/search?q=%22Wordle+226+X%22",
#     "promoted_content": null,
#     "query": "%22Wordle+226+X%22",
#     "tweet_volume": 20331
#    },
#    {
#     "name": "Konami",
#     "url": "http://twitter.com/search?q=Konami",
#     "promoted_content": null,
#     "query": "Konami",
#     "tweet_volume": 13274
#    },
#    {
#     "name": "Square Enix",
#     "url": "http://twitter.com/search?q=%22Square+Enix%22",
#     "promoted_content": null,
#     "query": "%22Square+Enix%22",
#     "tweet_volume": 13343
#    }
#   ],
#   "as_of": "2022-01-31T22:09:10Z",
#   "created_at": "2022-01-24T07:54:29Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ### Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'Trudeau', 'Halo', 'Nazis', 'Drake', 'PlayStation', 'Auba', 'Whoopi', 'Rihanna', 'Arsenal', 'Riri', 'Sony', 'Destiny', 'Bungie', 'Happy Lunar New Year', 'Activision'}

# %% [markdown]
# ## Search Results

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json


#q = "#Ada"
q = '#ECUTigers'

count = 1000

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = mathcs_twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = mathcs_twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Length of statuses 2
# Length of statuses 2
# [
#     {
#         "created_at": "Wed Jan 26 19:23:50 +0000 2022",
#         "id": 1486419627735281668,
#         "id_str": "1486419627735281668",
#         "text": "RT @ecoklibrary: The library is hiring student assistants right now! See open positions on Handshake: https://t.co/foDTl2we1L\n@ECUTigerUpda\u2026",
#         "truncated": false,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [
#                 {
#                     "screen_name": "ecoklibrary",
#                     "name": "Linscheid Library",
#                     "id": 1155847532607655938,
#                     "id_str": "1155847532607655938",
#                     "indices": [
#                         3,
#                         15
#                     ]
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/foDTl2we1L",
#                     "expanded_url": "https://joinhandshake.com",
#                     "display_url": "joinhandshake.com",
#                     "indices": [
#                         102,
#                         125
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 44617318,
#             "id_str": "44617318",
#             "name": "East Central University",
#             "screen_name": "ECUTigerUpdates",
#             "location": "Ada, Oklahoma",
#             "description": "East Central University is a public university offering Bachelor of Science, Bachelor of Arts and Master's degrees.",
#             "url": "https://t.co/NQLa15dvaR",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/NQLa15dvaR",
#                             "expanded_url": "http://www.ecok.edu",
#                             "display_url": "ecok.edu",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 5927,
#             "friends_count": 3470,
#             "listed_count": 57,
#             "created_at": "Thu Jun 04 13:41:14 +0000 2009",
#             "favourites_count": 4116,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": true,
#             "verified": false,
#             "statuses_count": 8190,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "C0DEED",
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1059580066097549312/3P9Tzsdf_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1059580066097549312/3P9Tzsdf_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/44617318/1637174793",
#             "profile_link_color": "FA743E",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": false,
#             "default_profile": false,
#             "default_profile_image": false,
#             "following": true,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "retweeted_status": {
#             "created_at": "Wed Jan 26 18:03:11 +0000 2022",
#             "id": 1486399334367252485,
#             "id_str": "1486399334367252485",
#             "text": "The library is hiring student assistants right now! See open positions on Handshake: https://t.co/foDTl2we1L\u2026 https://t.co/6YMZaDtfmz",
#             "truncated": true,
#             "entities": {
#                 "hashtags": [],
#                 "symbols": [],
#                 "user_mentions": [],
#                 "urls": [
#                     {
#                         "url": "https://t.co/foDTl2we1L",
#                         "expanded_url": "https://joinhandshake.com",
#                         "display_url": "joinhandshake.com",
#                         "indices": [
#                             85,
#                             108
#                         ]
#                     },
#                     {
#                         "url": "https://t.co/6YMZaDtfmz",
#                         "expanded_url": "https://twitter.com/i/web/status/1486399334367252485",
#                         "display_url": "twitter.com/i/web/status/1\u2026",
#                         "indices": [
#                             110,
#                             133
#                         ]
#                     }
#                 ]
#             },
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "source": "<a href=\"https://www.later.com\" rel=\"nofollow\">LaterMedia</a>",
#             "in_reply_to_status_id": null,
#             "in_reply_to_status_id_str": null,
#             "in_reply_to_user_id": null,
#             "in_reply_to_user_id_str": null,
#             "in_reply_to_screen_name": null,
#             "user": {
#                 "id": 1155847532607655938,
#                 "id_str": "1155847532607655938",
#                 "name": "Linscheid Library",
#                 "screen_name": "ecoklibrary",
#                 "location": "Ada, OK",
#                 "description": "Our mission is to collaborate with our community to provide access to resources and education, empowering users to transform our world.",
#                 "url": "https://t.co/yUBTDiS18x",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "url": "https://t.co/yUBTDiS18x",
#                                 "expanded_url": "http://ecok.libguides.com/home",
#                                 "display_url": "ecok.libguides.com/home",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ]
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "protected": false,
#                 "followers_count": 78,
#                 "friends_count": 123,
#                 "listed_count": 0,
#                 "created_at": "Mon Jul 29 14:28:21 +0000 2019",
#                 "favourites_count": 127,
#                 "utc_offset": null,
#                 "time_zone": null,
#                 "geo_enabled": false,
#                 "verified": false,
#                 "statuses_count": 525,
#                 "lang": null,
#                 "contributors_enabled": false,
#                 "is_translator": false,
#                 "is_translation_enabled": false,
#                 "profile_background_color": "F5F8FA",
#                 "profile_background_image_url": null,
#                 "profile_background_image_url_https": null,
#                 "profile_background_tile": false,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/1155850686829084673/HNiOGXlz_normal.jpg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/1155850686829084673/HNiOGXlz_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/1155847532607655938/1635797823",
#                 "profile_link_color": "1DA1F2",
#                 "profile_sidebar_border_color": "C0DEED",
#                 "profile_sidebar_fill_color": "DDEEF6",
#                 "profile_text_color": "333333",
#                 "profile_use_background_image": true,
#                 "has_extended_profile": true,
#                 "default_profile": true,
#                 "default_profile_image": false,
#                 "following": false,
#                 "follow_request_sent": false,
#                 "notifications": false,
#                 "translator_type": "none",
#                 "withheld_in_countries": []
#             },
#             "geo": null,
#             "coordinates": null,
#             "place": null,
#             "contributors": null,
#             "is_quote_status": false,
#             "retweet_count": 1,
#             "favorite_count": 3,
#             "favorited": false,
#             "retweeted": false,
#             "possibly_sensitive": false,
#             "lang": "en"
#         },
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 0,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     },
#     {
#         "created_at": "Wed Jan 26 18:03:11 +0000 2022",
#         "id": 1486399334367252485,
#         "id_str": "1486399334367252485",
#         "text": "The library is hiring student assistants right now! See open positions on Handshake: https://t.co/foDTl2we1L\u2026 https://t.co/6YMZaDtfmz",
#         "truncated": true,
#         "entities": {
#             "hashtags": [],
#             "symbols": [],
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "url": "https://t.co/foDTl2we1L",
#                     "expanded_url": "https://joinhandshake.com",
#                     "display_url": "joinhandshake.com",
#                     "indices": [
#                         85,
#                         108
#                     ]
#                 },
#                 {
#                     "url": "https://t.co/6YMZaDtfmz",
#                     "expanded_url": "https://twitter.com/i/web/status/1486399334367252485",
#                     "display_url": "twitter.com/i/web/status/1\u2026",
#                     "indices": [
#                         110,
#                         133
#                     ]
#                 }
#             ]
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "source": "<a href=\"https://www.later.com\" rel=\"nofollow\">LaterMedia</a>",
#         "in_reply_to_status_id": null,
#         "in_reply_to_status_id_str": null,
#         "in_reply_to_user_id": null,
#         "in_reply_to_user_id_str": null,
#         "in_reply_to_screen_name": null,
#         "user": {
#             "id": 1155847532607655938,
#             "id_str": "1155847532607655938",
#             "name": "Linscheid Library",
#             "screen_name": "ecoklibrary",
#             "location": "Ada, OK",
#             "description": "Our mission is to collaborate with our community to provide access to resources and education, empowering users to transform our world.",
#             "url": "https://t.co/yUBTDiS18x",
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "url": "https://t.co/yUBTDiS18x",
#                             "expanded_url": "http://ecok.libguides.com/home",
#                             "display_url": "ecok.libguides.com/home",
#                             "indices": [
#                                 0,
#                                 23
#                             ]
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "protected": false,
#             "followers_count": 78,
#             "friends_count": 123,
#             "listed_count": 0,
#             "created_at": "Mon Jul 29 14:28:21 +0000 2019",
#             "favourites_count": 127,
#             "utc_offset": null,
#             "time_zone": null,
#             "geo_enabled": false,
#             "verified": false,
#             "statuses_count": 525,
#             "lang": null,
#             "contributors_enabled": false,
#             "is_translator": false,
#             "is_translation_enabled": false,
#             "profile_background_color": "F5F8FA",
#             "profile_background_image_url": null,
#             "profile_background_image_url_https": null,
#             "profile_background_tile": false,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/1155850686829084673/HNiOGXlz_normal.jpg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/1155850686829084673/HNiOGXlz_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1155847532607655938/1635797823",
#             "profile_link_color": "1DA1F2",
#             "profile_sidebar_border_color": "C0DEED",
#             "profile_sidebar_fill_color": "DDEEF6",
#             "profile_text_color": "333333",
#             "profile_use_background_image": true,
#             "has_extended_profile": true,
#             "default_profile": true,
#             "default_profile_image": false,
#             "following": false,
#             "follow_request_sent": false,
#             "notifications": false,
#             "translator_type": "none",
#             "withheld_in_countries": []
#         },
#         "geo": null,
#         "coordinates": null,
#         "place": null,
#         "contributors": null,
#         "is_quote_status": false,
#         "retweet_count": 1,
#         "favorite_count": 3,
#         "favorited": false,
#         "retweeted": false,
#         "possibly_sensitive": false,
#         "lang": "en"
#     }
# ]

# %%
json.dumps(statuses[1])
# Out:
# '{"created_at": "Wed Jan 26 18:03:11 +0000 2022", "id": 1486399334367252485, "id_str": "1486399334367252485", "text": "The library is hiring student assistants right now! See open positions on Handshake: https://t.co/foDTl2we1L\\u2026 https://t.co/6YMZaDtfmz", "truncated": true, "entities": {"hashtags": [], "symbols": [], "user_mentions": [], "urls": [{"url": "https://t.co/foDTl2we1L", "expanded_url": "https://joinhandshake.com", "display_url": "joinhandshake.com", "indices": [85, 108]}, {"url": "https://t.co/6YMZaDtfmz", "expanded_url": "https://twitter.com/i/web/status/1486399334367252485", "display_url": "twitter.com/i/web/status/1\\u2026", "indices": [110, 133]}]}, "metadata": {"iso_language_code": "en", "result_type": "recent"}, "source": "<a href=\\"https://www.later.com\\" rel=\\"nofollow\\">LaterMedia</a>", "in_reply_to_status_id": null, "in_reply_to_status_id_str": null, "in_reply_to_user_id": null, "in_reply_to_user_id_str": null, "in_reply_to_screen_name": null, "user": {"id": 1155847532607655938, "id_str": "1155847532607655938", "name": "Linscheid Library", "screen_name": "ecoklibrary", "location": "Ada, OK", "description": "Our mission is to collaborate with our community to provide access to resources and education, empowering users to transform our world.", "url": "https://t.co/yUBTDiS18x", "entities": {"url": {"urls": [{"url": "https://t.co/yUBTDiS18x", "expanded_url": "http://ecok.libguides.com/home", "display_url": "ecok.libguides.com/home", "indices": [0, 23]}]}, "description": {"urls": []}}, "protected": false, "followers_count": 78, "friends_count": 123, "listed_count": 0, "created_at": "Mon Jul 29 14:28:21 +0000 2019", "favourites_count": 127, "utc_offset": null, "time_zone": null, "geo_enabled": false, "verified": false, "statuses_count": 525, "lang": null, "contributors_enabled": false, "is_translator": false, "is_translation_enabled": false, "profile_background_color": "F5F8FA", "profile_background_image_url": null, "profile_background_image_url_https": null, "profile_background_tile": false, "profile_image_url": "http://pbs.twimg.com/profile_images/1155850686829084673/HNiOGXlz_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1155850686829084673/HNiOGXlz_normal.jpg", "profile_banner_url": "https://pbs.twimg.com/profile_banners/1155847532607655938/1635797823", "profile_link_color": "1DA1F2", "profile_sidebar_border_color": "C0DEED", "profile_sidebar_fill_color": "DDEEF6", "profile_text_color": "333333", "profile_use_background_image": true, "has_extended_profile": true, "default_profile": true, "default_profile_image": false, "following": false, "follow_request_sent": false, "notifications": false, "translator_type": "none", "withheld_in_countries": []}, "geo": null, "coordinates": null, "place": null, "contributors": null, "is_quote_status": false, "retweet_count": 1, "favorite_count": 3, "favorited": false, "retweeted": false, "possibly_sensitive": false, "lang": "en"}'

# %% [markdown]
# ### Extracting text, screen names, and hashtags from tweets

# %%
import time


status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1))
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @ecoklibrary: The library is hiring student assistants right now! See open positions on Handshake: https://t.co/foDTl2we1L\n@ECUTigerUpda\u2026",
#  "The library is hiring student assistants right now! See open positions on Handshake: https://t.co/foDTl2we1L\u2026 https://t.co/6YMZaDtfmz"
# ]
# [
#  "ecoklibrary"
# ]
# []
# [
#  "RT",
#  "@ecoklibrary:",
#  "The",
#  "library",
#  "is"
# ]

# %%
update = ""

for i in range (0,len(status_texts)):
    update = update + status_texts[i]

# %%
update
# Out:
# 'RT @ecoklibrary: The library is hiring student assistants right now! See open positions on Handshake: https://t.co/foDTl2we1L\n@ECUTigerUpda…The library is hiring student assistants right now! See open positions on Handshake: https://t.co/foDTl2we1L… https://t.co/6YMZaDtfmz'

# %% [markdown]
# ### Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter



for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
# Out:
# [('RT', 30), ('to', 22), ('is', 20), ('you', 19), ('this', 17), ('for', 15), ('the', 14), ('a', 13), ('t-shirt', 12), ('in', 11)]
# [('ecu_oil', 11), ('ECUTigerUpdates', 9), ('ECUAlumni_Fndtn', 5), ('ECUTigersSB', 4), ('brimooreee', 3), ('Diegs_11', 3), ('BaldwinJalen', 2), ('celena0311', 1), ('cs_ecu', 1), ('ECUroar', 1)]
# [('ECUTigers', 17), ('ecutigersfb', 9), ('hearourroar', 9), ('ECUTIGERS', 9), ('SeniorDay', 4), ('ECUTigersChickasawAppreciationDay', 3), ('Jbal', 2), ('corner', 2), ('ProudTigerMom', 2), ('aintnomountainhighenough', 2)]

# %%
words
# Out:
# ['RT',
#  '@ECUTigerUpdates:',
#  'Take',
#  'time',
#  'to',
#  'check',
#  'out',
#  'the',
#  'new',
#  'Digital',
#  'Humanities',
#  'Lab',
#  'in',
#  'the',
#  'Linscheid',
#  'Library.',
#  'The',
#  'open',
#  'house',
#  'is',
#  'today',
#  'from',
#  '3-4:30pm…',
#  'We',
#  'hope',
#  'you’re',
#  'enjoying',
#  'our',
#  '“Meet',
#  'the',
#  'Employees”',
#  'video',
#  'series!',
#  'This',
#  'is',
#  'Ada',
#  'native',
#  'Chance',
#  'Branscum,',
#  'our',
#  'Senior',
#  'Vice…',
#  'https://t.co/MMQ4kgfLD7',
#  'RT',
#  '@ECUTigerUpdates:',
#  'Take',
#  'time',
#  'to',
#  'check',
#  'out',
#  'the',
#  'new',
#  'Digital',
#  'Humanities',
#  'Lab',
#  'in',
#  'the',
#  'Linscheid',
#  'Library.',
#  'The',
#  'open',
#  'house',
#  'is',
#  'today',
#  'from',
#  '3-4:30pm…',
#  'Take',
#  'time',
#  'to',
#  'check',
#  'out',
#  'the',
#  'new',
#  'Digital',
#  'Humanities',
#  'Lab',
#  'in',
#  'the',
#  'Linscheid',
#  'Library.',
#  'The',
#  'open',
#  'house',
#  'is',
#  'today',
#  'from',
#  '3-4:30…',
#  'https://t.co/DWiQrJW57F',
#  'Your',
#  'Voice',
#  'is',
#  'Needed:',
#  'Please',
#  'take',
#  'our',
#  'library',
#  'use',
#  'survey',
#  'to',
#  'enter',
#  'a',
#  'drawing',
#  'for',
#  'a',
#  '$25',
#  'Amazon',
#  'gift',
#  'card!',
#  'The',
#  'estimat…',
#  'https://t.co/K6zlmFg7xO',
#  'RT',
#  '@brimooreee:',
#  'Had',
#  'a',
#  'great',
#  'official',
#  'visit',
#  'at',
#  'East',
#  'Central',
#  'University',
#  'this',
#  'weekend,',
#  'thank',
#  'you',
#  '@ECUTigersSB',
#  'for',
#  'having',
#  'me!',
#  '🐾\U0001f9e1',
#  '#ECUTige…',
#  'RT',
#  '@ECUTigerUpdates:',
#  'Thank',
#  'you',
#  'Governor',
#  'Anoatubby',
#  'for',
#  'celebrating',
#  'Chickasaw',
#  'Nation',
#  'Appreciation',
#  'Day',
#  'with',
#  'us!',
#  '#ecutigersfb',
#  '#hearourroar',
#  '#ECU…',
#  'RT',
#  '@brimooreee:',
#  'Had',
#  'a',
#  'great',
#  'official',
#  'visit',
#  'at',
#  'East',
#  'Central',
#  'University',
#  'this',
#  'weekend,',
#  'thank',
#  'you',
#  '@ECUTigersSB',
#  'for',
#  'having',
#  'me!',
#  '🐾\U0001f9e1',
#  '#ECUTige…',
#  'RT',
#  '@brimooreee:',
#  'Had',
#  'a',
#  'great',
#  'official',
#  'visit',
#  'at',
#  'East',
#  'Central',
#  'University',
#  'this',
#  'weekend,',
#  'thank',
#  'you',
#  '@ECUTigersSB',
#  'for',
#  'having',
#  'me!',
#  '🐾\U0001f9e1',
#  '#ECUTige…',
#  'RT',
#  '@ECUTigerUpdates:',
#  'Thank',
#  'you',
#  'Governor',
#  'Anoatubby',
#  'for',
#  'celebrating',
#  'Chickasaw',
#  'Nation',
#  'Appreciation',
#  'Day',
#  'with',
#  'us!',
#  '#ecutigersfb',
#  '#hearourroar',
#  '#ECU…',
#  'Had',
#  'a',
#  'great',
#  'official',
#  'visit',
#  'at',
#  'East',
#  'Central',
#  'University',
#  'this',
#  'weekend,',
#  'thank',
#  'you',
#  '@ECUTigersSB',
#  'for',
#  'having',
#  'me!',
#  '🐾\U0001f9e1…',
#  'https://t.co/qSgMdXYoxM',
#  'RT',
#  '@ECUTigerUpdates:',
#  'Proud',
#  'to',
#  'be',
#  'a',
#  'Tiger',
#  'even',
#  'in',
#  'the',
#  'rain!',
#  '#ecutigersfb',
#  '#hearourroar',
#  '#ECUTigers',
#  '#ECUTigersChickasawAppreciationDay',
#  'https://…',
#  'RT',
#  '@ECUTigerUpdates:',
#  'Proud',
#  'to',
#  'be',
#  'a',
#  'Tiger',
#  'even',
#  'in',
#  'the',
#  'rain!',
#  '#ecutigersfb',
#  '#hearourroar',
#  '#ECUTigers',
#  '#ECUTigersChickasawAppreciationDay',
#  'https://…',
#  'RT',
#  '@ECUTigerUpdates:',
#  'Thank',
#  'you',
#  'Governor',
#  'Anoatubby',
#  'for',
#  'celebrating',
#  'Chickasaw',
#  'Nation',
#  'Appreciation',
#  'Day',
#  'with',
#  'us!',
#  '#ecutigersfb',
#  '#hearourroar',
#  '#ECU…',
#  'RT',
#  '@ECUTigerUpdates:',
#  'Thank',
#  'you',
#  'Governor',
#  'Anoatubby',
#  'for',
#  'celebrating',
#  'Chickasaw',
#  'Nation',
#  'Appreciation',
#  'Day',
#  'with',
#  'us!',
#  '#ecutigersfb',
#  '#hearourroar',
#  '#ECU…',
#  'RT',
#  '@celena0311:',
#  'When',
#  '@BaldwinJalen',
#  'is',
#  'on',
#  'you,',
#  'you',
#  'get',
#  'no',
#  'yards.',
#  '#Jbal',
#  '#corner',
#  '#ECUTigers',
#  '#ProudTigerMom',
#  '#aintnomountainhighenough',
#  '#tokeepme…',
#  'Proud',
#  'to',
#  'be',
#  'a',
#  'Tiger',
#  'even',
#  'in',
#  'the',
#  'rain!',
#  '#ecutigersfb',
#  '#hearourroar',
#  '#ECUTigers',
#  '#ECUTigersChickasawAppreciationDay',
#  'https://t.co/zgSIalqLOA',
#  'RT',
#  '@ECUTigerUpdates:',
#  'Thank',
#  'you',
#  'Governor',
#  'Anoatubby',
#  'for',
#  'celebrating',
#  'Chickasaw',
#  'Nation',
#  'Appreciation',
#  'Day',
#  'with',
#  'us!',
#  '#ecutigersfb',
#  '#hearourroar',
#  '#ECU…',
#  'Thank',
#  'you',
#  'Governor',
#  'Anoatubby',
#  'for',
#  'celebrating',
#  'Chickasaw',
#  'Nation',
#  'Appreciation',
#  'Day',
#  'with',
#  'us!',
#  '#ecutigersfb',
#  '#hearourroar…',
#  'https://t.co/E3HirdDIef',
#  'When',
#  '@BaldwinJalen',
#  'is',
#  'on',
#  'you,',
#  'you',
#  'get',
#  'no',
#  'yards.',
#  '#Jbal',
#  '#corner',
#  '#ECUTigers',
#  '#ProudTigerMom',
#  '#aintnomountainhighenough…',
#  'https://t.co/zEZyOUMGA1',
#  'RT',
#  '@ECUAlumni_Fndtn:',
#  '#ECUTigers!',
#  '👀',
#  'Have',
#  'you',
#  'bought',
#  'this',
#  'amazing',
#  't-shirt',
#  'from',
#  '@ecu_oil',
#  'yet?',
#  'Once',
#  'a',
#  'semester,',
#  'OIL',
#  'spends',
#  '5',
#  'days',
#  'in',
#  'OKC',
#  'while…',
#  'RT',
#  '@ECUAlumni_Fndtn:',
#  '#ECUTigers!',
#  '👀',
#  'Have',
#  'you',
#  'bought',
#  'this',
#  'amazing',
#  't-shirt',
#  'from',
#  '@ecu_oil',
#  'yet?',
#  'Once',
#  'a',
#  'semester,',
#  'OIL',
#  'spends',
#  '5',
#  'days',
#  'in',
#  'OKC',
#  'while…',
#  'RT',
#  '@ECUAlumni_Fndtn:',
#  '#ECUTigers!',
#  'The',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature,',
#  'at',
#  'East',
#  'Central',
#  'University',
#  '(ECU)',
#  'is',
#  'selling',
#  'shirts',
#  'to',
#  'fund',
#  'thei…',
#  '#ECUTigers!',
#  '👀',
#  'Have',
#  'you',
#  'bought',
#  'this',
#  'amazing',
#  't-shirt',
#  'from',
#  '@ecu_oil',
#  'yet?',
#  'Once',
#  'a',
#  'semester,',
#  'OIL',
#  'spends',
#  '5',
#  'days',
#  'in',
#  'OKC',
#  'wh…',
#  'https://t.co/Q6JTh3DWSV',
#  '#ECUTigers!',
#  'The',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature,',
#  'at',
#  'East',
#  'Central',
#  'University',
#  '(ECU)',
#  'is',
#  'selling',
#  'shirts',
#  'to',
#  'fund',
#  't…',
#  'https://t.co/IiuU1qdiKt',
#  '#ECUTigers',
#  'are',
#  'talking',
#  'about',
#  'ECUTigers',
#  'today',
#  'on',
#  '2018-10-09',
#  '@cs_ecu',
#  'The',
#  'East',
#  'Central',
#  'University',
#  'StudentCPT',
#  'chapter',
#  'is',
#  'hosting',
#  'a',
#  'meeting',
#  'tonight',
#  'at',
#  '7',
#  'p.m.',
#  'The',
#  'student',
#  'leaders',
#  'will',
#  'be',
#  'b…',
#  'https://t.co/h9l6gKmErZ',
#  'RT',
#  '@ecu_oil:',
#  'ATTN',
#  '#ECUTIGERS!',
#  'Our',
#  'ECU',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature',
#  'delegation',
#  'is',
#  'selling',
#  'this',
#  'really',
#  'cute',
#  't-shirt',
#  'to',
#  'raise',
#  'money',
#  'f…',
#  'RT',
#  '@ecu_oil:',
#  'ATTN',
#  '#ECUTIGERS!',
#  'Our',
#  'ECU',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature',
#  'delegation',
#  'is',
#  'selling',
#  'this',
#  'really',
#  'cute',
#  't-shirt',
#  'to',
#  'raise',
#  'money',
#  'f…',
#  'RT',
#  '@Diegs_11:',
#  'Welcome',
#  'to',
#  'all',
#  'visiting',
#  'high',
#  'school',
#  'seniors',
#  'who',
#  'are',
#  'on',
#  'campus',
#  'for',
#  '#SeniorDay!',
#  'We',
#  'hope',
#  'you',
#  'enjoy',
#  'your',
#  'Tiger',
#  'experience.',
#  '#ECUT…',
#  'RT',
#  '@Diegs_11:',
#  'Welcome',
#  'to',
#  'all',
#  'visiting',
#  'high',
#  'school',
#  'seniors',
#  'who',
#  'are',
#  'on',
#  'campus',
#  'for',
#  '#SeniorDay!',
#  'We',
#  'hope',
#  'you',
#  'enjoy',
#  'your',
#  'Tiger',
#  'experience.',
#  '#ECUT…',
#  'RT',
#  '@Diegs_11:',
#  'Welcome',
#  'to',
#  'all',
#  'visiting',
#  'high',
#  'school',
#  'seniors',
#  'who',
#  'are',
#  'on',
#  'campus',
#  'for',
#  '#SeniorDay!',
#  'We',
#  'hope',
#  'you',
#  'enjoy',
#  'your',
#  'Tiger',
#  'experience.',
#  '#ECUT…',
#  'Welcome',
#  'to',
#  'all',
#  'visiting',
#  'high',
#  'school',
#  'seniors',
#  'who',
#  'are',
#  'on',
#  'campus',
#  'for',
#  '#SeniorDay!',
#  'We',
#  'hope',
#  'you',
#  'enjoy',
#  'your',
#  'Tiger',
#  'experience.',
#  '#ECUTigers',
#  '@ECUroar',
#  'RT',
#  '@ECUAlumni_Fndtn:',
#  'Hey',
#  'future',
#  'and',
#  'current',
#  '#ECUTigers,',
#  'come',
#  'see',
#  'us',
#  'at',
#  'the',
#  'ECU',
#  'Majors',
#  'Fair',
#  'in',
#  'the',
#  'ballroom',
#  'today',
#  'from',
#  '10AM-1:30PM!',
#  'https://…',
#  'Hey',
#  'future',
#  'and',
#  'current',
#  '#ECUTigers,',
#  'come',
#  'see',
#  'us',
#  'at',
#  'the',
#  'ECU',
#  'Majors',
#  'Fair',
#  'in',
#  'the',
#  'ballroom',
#  'today',
#  'from',
#  '10AM-1:30PM!',
#  'https://t.co/5M0qGGabde',
#  'RT',
#  '@ecu_oil:',
#  'ATTN',
#  '#ECUTIGERS!',
#  'Our',
#  'ECU',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature',
#  'delegation',
#  'is',
#  'selling',
#  'this',
#  'really',
#  'cute',
#  't-shirt',
#  'to',
#  'raise',
#  'money',
#  'f…',
#  'RT',
#  '@ecu_oil:',
#  'ATTN',
#  '#ECUTIGERS!',
#  'Our',
#  'ECU',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature',
#  'delegation',
#  'is',
#  'selling',
#  'this',
#  'really',
#  'cute',
#  't-shirt',
#  'to',
#  'raise',
#  'money',
#  'f…',
#  'RT',
#  '@ecu_oil:',
#  'ATTN',
#  '#ECUTIGERS!',
#  'Our',
#  'ECU',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature',
#  'delegation',
#  'is',
#  'selling',
#  'this',
#  'really',
#  'cute',
#  't-shirt',
#  'to',
#  'raise',
#  'money',
#  'f…',
#  'RT',
#  '@ecu_oil:',
#  'ATTN',
#  '#ECUTIGERS!',
#  'Our',
#  'ECU',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature',
#  'delegation',
#  'is',
#  'selling',
#  'this',
#  'really',
#  'cute',
#  't-shirt',
#  'to',
#  'raise',
#  'money',
#  'f…',
#  'RT',
#  '@ecu_oil:',
#  'ATTN',
#  '#ECUTIGERS!',
#  'Our',
#  'ECU',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature',
#  'delegation',
#  'is',
#  'selling',
#  'this',
#  'really',
#  'cute',
#  't-shirt',
#  'to',
#  'raise',
#  'money',
#  'f…',
#  'RT',
#  '@ecu_oil:',
#  'ATTN',
#  '#ECUTIGERS!',
#  'Our',
#  'ECU',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature',
#  'delegation',
#  'is',
#  'selling',
#  'this',
#  'really',
#  'cute',
#  't-shirt',
#  'to',
#  'raise',
#  'money',
#  'f…',
#  'ATTN',
#  '#ECUTIGERS!',
#  'Our',
#  'ECU',
#  'Oklahoma',
#  'Intercollegiate',
#  'Legislature',
#  'delegation',
#  'is',
#  'selling',
#  'this',
#  'really',
#  'cute',
#  't-shirt',
#  'to',
#  'ra…',
#  'https://t.co/HA4lwVVjpt',
#  'RT',
#  '@HireATiger:',
#  'Love',
#  'our',
#  'Pride',
#  'of',
#  'Tigerland!!!',
#  'You',
#  'guys',
#  'are',
#  'amazing!!!',
#  '#tigerpalooza',
#  '#ecok',
#  '#ECUTigers',
#  'Love',
#  'our',
#  'Pride',
#  'of',
#  'Tigerland!!!',
#  'You',
#  'guys',
#  'are',
#  'amazing!!!',
#  '#tigerpalooza',
#  '#ecok',
#  '#ECUTigers',
#  'RT',
#  '@ECUAlumni_Fndtn:',
#  'GUESS',
#  'WHAT',
#  '#ECUTigers?!',
#  'Our',
#  'new',
#  'prize',
#  'wheel',
#  'is',
#  'here!',
#  '😍',
#  "You'll",
#  'be',
#  'seeing',
#  'this',
#  'bad',
#  'boy',
#  'during',
#  'Homecoming',
#  'and',
#  'other',
#  'eve…']

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pa


stupid= ["hi",'bye']
columns=["word"]
pa.DataFrame(stupid,  columns = columns)


stopwords = set(STOPWORDS)




wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(update)

# plot the WordCloud image                       
plt.figure(figsize = (8, 8))
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

#plt.show()
plt.savefig('img.png')

# %%
from PIL import Image

im = Image.open('img.png')

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=576x576 at 0x7F0497BE2240>

# %% [markdown]
# ### Using Prettytable

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +---------+-------+
# | Word    | Count |
# +---------+-------+
# | RT      |    30 |
# | to      |    22 |
# | is      |    20 |
# | you     |    19 |
# | this    |    17 |
# | for     |    15 |
# | the     |    14 |
# | a       |    13 |
# | t-shirt |    12 |
# | in      |    11 |
# +---------+-------+
# +-----------------+-------+
# | Screen Name     | Count |
# +-----------------+-------+
# | ecu_oil         |    11 |
# | ECUTigerUpdates |     9 |
# | ECUAlumni_Fndtn |     5 |
# | ECUTigersSB     |     4 |
# | brimooreee      |     3 |
# | Diegs_11        |     3 |
# | BaldwinJalen    |     2 |
# | celena0311      |     1 |
# | cs_ecu          |     1 |
# | ECUroar         |     1 |
# +-----------------+-------+
# +-----------------------------------+-------+
# | Hashtag                           | Count |
# +-----------------------------------+-------+
# | ECUTigers                         |    17 |
# | ecutigersfb                       |     9 |
# | hearourroar                       |     9 |
# | ECUTIGERS                         |     9 |
# | SeniorDay                         |     4 |
# | ECUTigersChickasawAppreciationDay |     3 |
# | Jbal                              |     2 |
# | corner                            |     2 |
# | ProudTigerMom                     |     2 |
# | aintnomountainhighenough          |     2 |
# +-----------------------------------+-------+

# %% [markdown]
# ### Calculating Lexical Diversity

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.2688296639629201
# 0.2682926829268293
# 0.19047619047619047
# 19.177777777777777

# %% [markdown]
# ### Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+-------------+----------------------------------------------------+
# | Count | Screen Name | Text                                               |
# +-------+-------------+----------------------------------------------------+
# | 10    | ecu_oil     | RT @ecu_oil: ATTN #ECUTIGERS!                      |
# |       |             |                                                    |
# |       |             | Our ECU Oklahoma Intercollegiate Legislature       |
# |       |             | delegation is selling this really cute t-shirt to  |
# |       |             | raise money f…                                     |
# | 10    | ecu_oil     | RT @ecu_oil: ATTN #ECUTIGERS!                      |
# |       |             |                                                    |
# |       |             | Our ECU Oklahoma Intercollegiate Legislature       |
# |       |             | delegation is selling this really cute t-shirt to  |
# |       |             | raise money f…                                     |
# | 10    | ecu_oil     | RT @ecu_oil: ATTN #ECUTIGERS!                      |
# |       |             |                                                    |
# |       |             | Our ECU Oklahoma Intercollegiate Legislature       |
# |       |             | delegation is selling this really cute t-shirt to  |
# |       |             | raise money f…                                     |
# | 10    | ecu_oil     | RT @ecu_oil: ATTN #ECUTIGERS!                      |
# |       |             |                                                    |
# |       |             | Our ECU Oklahoma Intercollegiate Legislature       |
# |       |             | delegation is selling this really cute t-shirt to  |
# |       |             | raise money f…                                     |
# | 10    | ecu_oil     | RT @ecu_oil: ATTN #ECUTIGERS!                      |
# |       |             |                                                    |
# |       |             | Our ECU Oklahoma Intercollegiate Legislature       |
# |       |             | delegation is selling this really cute t-shirt to  |
# |       |             | raise money f…                                     |
# +-------+-------------+----------------------------------------------------+

# %% [markdown]
# ### Plotting frequencies of words

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  


word_counts = sorted(Counter(words).values(), reverse=True)



plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# ### Posting It Back on the Web

# %%
import datetime
now = datetime.datetime.now()

print(now)
# Out:
# 2022-01-31 22:06:50.050192

# %%
popular = c.most_common()[0][0]

now = datetime.date(now.year,now.month,now.day)

print(now)
# Out:
# 2018-10-16

# %%
mathcs_twitter_api.statuses.update(
    status="#ECUTigers are talking about {} today on {} @cs_ecu".format(popular,now))
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Oct 16 21:21:00 +0000 2018',
#  'entities': {'hashtags': [{'indices': [0, 10], 'text': 'ECUTigers'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 1037047347405045760,
#     'id_str': '1037047347405045760',
#     'indices': [59, 66],
#     'name': 'ECU_Math/CS',
#     'screen_name': 'cs_ecu'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1052308450976378880,
#  'id_str': '1052308450976378880',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://ecok.edu/academics/colleges-and-schools/college-health-and-sciences/department-mathematics-and-computer" rel="nofollow">Starlas Data Project</a>',
#  'text': '#ECUTigers are talking about ECUTigers today on 2018-10-16 @cs_ecu',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Tue Sep 04 18:38:49 +0000 2018',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': '',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'bit.ly/2NfSiTh',
#       'expanded_url': 'https://bit.ly/2NfSiTh',
#       'indices': [0, 23],
#       'url': 'https://t.co/PugruxKlLL'}]}},
#   'favourites_count': 0,
#   'follow_request_sent': False,
#   'followers_count': 5,
#   'following': False,
#   'friends_count': 29,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 1037047347405045760,
#   'id_str': '1037047347405045760',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 0,
#   'location': 'Ada, OK',
#   'name': 'ECU_Math/CS',
#   'notifications': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1037047347405045760/1536096251',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1037089960514310144/Kk2ypzpr_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1037089960514310144/Kk2ypzpr_normal.jpg',
#   'profile_link_color': 'FF5400',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'cs_ecu',
#   'statuses_count': 6,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/PugruxKlLL',
#   'utc_offset': None,
#   'verified': False}}

# %%
mathcs_twitter_api.statuses.update(
    status="#ECUTigers are talking about {} today on {} @cs_ecu".format(popular,now))
# Out:
#   File "<ipython-input-73-4f32b376ab6a>", line 1
#     nurfnick_twitter_api.statuses.update_with_media("media[]":"im",
#                                                              ^
# SyntaxError: invalid syntax

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %%
retweets[1]
# Out:
# ('ECUTigerUpdates',
#  'RT @ECUTigerUpdates: Take time to check out the new Digital Humanities Lab in the Linscheid Library. The open house is today from 3-4:30pm…')

# %%
mathcs_twitter_api.statuses.update(
    status="#ECUTigers are saying `{}` today on {} @cs_ecu".format(retweets[1],now))
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Oct 16 21:29:54 +0000 2018',
#  'entities': {'hashtags': [{'indices': [0, 10], 'text': 'ECUTigers'}],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#     'expanded_url': 'https://twitter.com/i/web/status/1052310693339439104',
#     'indices': [116, 139],
#     'url': 'https://t.co/Pp9R3Z0hMr'}],
#   'user_mentions': [{'id': 44617318,
#     'id_str': '44617318',
#     'indices': [47, 63],
#     'name': 'East Central Univ.',
#     'screen_name': 'ECUTigerUpdates'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1052310693339439104,
#  'id_str': '1052310693339439104',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://ecok.edu/academics/colleges-and-schools/college-health-and-sciences/department-mathematics-and-computer" rel="nofollow">Starlas Data Project</a>',
#  'text': "#ECUTigers are saying `('ECUTigerUpdates', 'RT @ECUTigerUpdates: Take time to check out the new Digital Humanities… https://t.co/Pp9R3Z0hMr",
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Tue Sep 04 18:38:49 +0000 2018',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': '',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'bit.ly/2NfSiTh',
#       'expanded_url': 'https://bit.ly/2NfSiTh',
#       'indices': [0, 23],
#       'url': 'https://t.co/PugruxKlLL'}]}},
#   'favourites_count': 0,
#   'follow_request_sent': False,
#   'followers_count': 5,
#   'following': False,
#   'friends_count': 29,
#   'geo_enabled': False,
#   'has_extended_profile': False,
#   'id': 1037047347405045760,
#   'id_str': '1037047347405045760',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 0,
#   'location': 'Ada, OK',
#   'name': 'ECU_Math/CS',
#   'notifications': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1037047347405045760/1536096251',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1037089960514310144/Kk2ypzpr_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1037089960514310144/Kk2ypzpr_normal.jpg',
#   'profile_link_color': 'FF5400',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'cs_ecu',
#   'statuses_count': 8,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/PugruxKlLL',
#   'utc_offset': None,
#   'verified': False}}

# %% [markdown]
# ## Getting Home Pages and Past Tweets

# %% [markdown]
# We can grab the home timeline from our user.

# %%
len(mathcs_twitter_api.statuses.home_timeline())
# Out:
# 20

# %% [markdown]
# Or another user

# %%
len(mathcs_twitter_api.statuses.user_timeline(screen_name="nurfnick"))
# Out:
# 20

# %% [markdown]
# I am going to guess here that the API is limiting me to only the past 20 tweets.  You'll find that there are lots of limits in the API!

# %% [markdown]
# ## Your Turn

# %% [markdown]
# Using either the math_cs credentials or your own;
#
# 1. Get authenticated to twitter.
# 2. Find the top trending 10 topics in the world and display them by name
# 3. Search for your favorite show, actor, sports team or player and see what twitter is saying about them.
