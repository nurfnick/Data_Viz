# %% [markdown]
# <a href="https://colab.research.google.com/github/camdenlol/Data_Viz/blob/main/Content/Solutions/CamdenSolutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Camden Wilmes

# %%
import pandas as pd

# %% [markdown]
# ## 01 python

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Data_Sets/iris.csv') #you do have headers in this dataset
df
# Out:
#      SepalLength  SepalWidth  PedalLength  PedalWidth           Class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#import pandas as pd only need to load pandas once this entire document!
df.head()
# Out:
#    SepalLength  SepalWidth  PedalLength  PedalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PedalLength', 'PedalWidth', 'Class'], dtype='object')

# %%
df.groupby('SepalLength').mean()
# Out:
# <ipython-input-5-92b0c3e71f9d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('SepalLength').mean()
#              SepalWidth  PedalLength  PedalWidth
# SepalLength
# 4.3            3.000000     1.100000    0.100000
# 4.4            3.033333     1.333333    0.200000
# 4.5            2.300000     1.300000    0.300000
# 4.6            3.325000     1.325000    0.225000
# 4.7            3.200000     1.450000    0.200000
# 4.8            3.180000     1.580000    0.200000
# 4.9            2.866667     2.283333    0.533333
# 5.0            3.120000     1.840000    0.430000
# 5.1            3.477778     1.722222    0.400000
# 5.2            3.425000     2.075000    0.475000
# 5.3            3.700000     1.500000    0.200000
# 5.4            3.550000     2.033333    0.516667
# ...

# %%
dfg = df.groupby('Class')['Class'].count()

# %%
df['Class']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Class, Length: 150, dtype: object

# %%
dfg.plot(kind='bar', title='Classes of Iris', ylabel='Number of Classes', xlabel='Class', figsize=(6,5))
# Out:
# <Axes: title={'center': 'Classes of Iris'}, xlabel='Class', ylabel='Number of Classes'>

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
import seaborn as sns

# %%
sns.violinplot(data = df)
# Out:
# <Axes: >

# %% [markdown]
# star rating: probably like a 3 average. in the beginning i was completely lost but once it clicked it was a 1.

# %% [markdown]
# ##02 pandas

# %% [markdown]
# you should fix these errors:
#
# acsessing the data
#
# colmuns in the melt pivot line

# %%
iris = df

# %%
iris.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PedalLength', 'PedalWidth', 'Class'], dtype='object')

# %%
iris[['SepalLength']]
# Out:
#      SepalLength
# 0            5.1
# 1            4.9
# 2            4.7
# 3            4.6
# 4            5.0
# ..           ...
# 145          6.7
# 146          6.3
# 147          6.5
# 148          6.2
# 149          5.9
#
# [150 rows x 1 columns]

# %%
iris.SepalLength.mean()
# Out:
# 5.843333333333334

# %%
iris
# Out:
#      SepalLength  SepalWidth  PedalLength  PedalWidth           Class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df_melt = iris.melt(id_vars = 'Class',
value_vars = ['SepalLength', 'PedalLength'],
var_name = 'Columns')

df_melt
# Out:
#               Class      Columns  value
# 0       Iris-setosa  SepalLength    5.1
# 1       Iris-setosa  SepalLength    4.9
# 2       Iris-setosa  SepalLength    4.7
# 3       Iris-setosa  SepalLength    4.6
# 4       Iris-setosa  SepalLength    5.0
# ..              ...          ...    ...
# 295  Iris-virginica  PedalLength    5.2
# 296  Iris-virginica  PedalLength    5.0
# 297  Iris-virginica  PedalLength    5.2
# 298  Iris-virginica  PedalLength    5.4
# 299  Iris-virginica  PedalLength    5.1
#
# [300 rows x 3 columns]

# %% [markdown]
# ok i think i melted that correctly but i dont really know what i did other than condense the table...? also i think i asked for it to show sepal length and pedal length but only pedal length is showing...?

# %%
iris.loc[(iris.PedalLength>5) & (iris.SepalLength <7)]
# Out:
#      SepalLength  SepalWidth  PedalLength  PedalWidth            Class
# 83           6.0         2.7          5.1         1.6  Iris-versicolor
# 100          6.3         3.3          6.0         2.5   Iris-virginica
# 101          5.8         2.7          5.1         1.9   Iris-virginica
# 103          6.3         2.9          5.6         1.8   Iris-virginica
# 104          6.5         3.0          5.8         2.2   Iris-virginica
# 108          6.7         2.5          5.8         1.8   Iris-virginica
# 110          6.5         3.2          5.1         2.0   Iris-virginica
# 111          6.4         2.7          5.3         1.9   Iris-virginica
# 112          6.8         3.0          5.5         2.1   Iris-virginica
# 114          5.8         2.8          5.1         2.4   Iris-virginica
# 115          6.4         3.2          5.3         2.3   Iris-virginica
# 116          6.5         3.0          5.5         1.8   Iris-virginica
# ...

# %% [markdown]
# sooo there are no items here and the mean and median of nothing is zero. i do not think i did this correct but i did use the code you sent me...? i will ask you tomorrow during our meeting at 1. 3 star difficulty.

# %%
iris.groupby("Class").agg(['mean','median'])
# Out:
#                 SepalLength        SepalWidth        PedalLength         \
#                        mean median       mean median        mean median
# Class
# Iris-setosa           5.006    5.0      3.418    3.4       1.464   1.50
# Iris-versicolor       5.936    5.9      2.770    2.8       4.260   4.35
# Iris-virginica        6.588    6.5      2.974    3.0       5.552   5.55
#
#                 PedalWidth
#                       mean median
# Class
# Iris-setosa          0.244    0.2
# Iris-versicolor      1.326    1.3
# Iris-virginica       2.026    2.0

# %% [markdown]
# ## 03 SQL (1)

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# %%bigquery --project dataviz24
# SELECT
#   COUNT(*) as total_rows
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    total_rows
# 0     2130009

# %% [markdown]
# 2130009 entries

# %%
# %%bigquery --project dataviz24
# SELECT
# GREATEST(duration_minutes) AS max_value
# from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          max_value
# 0              128
# 1              161
# 2               66
# 3               56
# 4               57
# ...            ...
# 2130004         43
# 2130005         43
# 2130006         43
# 2130007         43
# 2130008         43
#
# [2130009 rows x 1 columns]

# %% [markdown]
# i do not like that

# %%
# %%bigquery --project dataviz24
# SELECT
# MAX(duration_minutes)
# from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      f0_
# 0  34238

# %% [markdown]
# 34,238 minutes

# %%
# %%bigquery --project dataviz24
# SELECT
# AVG(duration_minutes)
# from `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#          f0_
# 0  29.293437

# %% [markdown]
# 29 minutes is the average time for a trip

# %% [markdown]
# probably like a 1 star rating if i would have understood how to actually start lol

# %% [markdown]
# ## 04 SQL (2)

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# %%bigquery --project dataviz24
# SELECT *
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     trip_id       subscriber_type bike_id bike_type                start_time  \
# 0   4163661  24 Hour Walk Up Pass     478   classic 2015-03-18 00:34:31+00:00
# 1  30125269               Local31   21688  electric 2023-07-05 15:47:43+00:00
# 2   4149702              Local365      36   classic 2015-03-17 00:42:56+00:00
# 3   4144959  24 Hour Walk Up Pass     558   classic 2015-03-16 16:49:18+00:00
# 4   4142940  24 Hour Walk Up Pass     772   classic 2015-03-16 15:35:34+00:00
#
#    start_station_id                     start_station_name end_station_id  \
# 0              2564                       5th & San Marcos           2562
# 1              3790             Lake Austin Blvd/Deep Eddy           3790
# 2              2540                         17th/Guadalupe           2544
# 3              3293               Barton Springs/Riverside           2550
# ...

# %%
# %%bigquery --project dataviz24
# SELECT DISTINCT start_station_name
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                    start_station_name
# 0            ACC - West & 12th Street
# 1             ACC - Rio Grande & 12th
# 2                        Lavaca & 6th
# 3             Toomey Rd @ South Lamar
# 4                Ready for deployment
# ..                                ...
# 196   5th/Guadalupe @ Republic Square
# 197             cesar Chavez/Congress
# 198  23rd & San Jacinto @ DKR Stadium
# 199        Nash Hernandez @ RBJ South
# 200       Lakeshore & Pleasant Valley
#
# [201 rows x 1 columns]

# %% [markdown]
# i just did this to see how many different stations there were

# %%
# %%bigquery --project dataviz24
# SELECT
# AVG(duration_minutes) as Average_Duration_In_Minutes, Start_Station_Name
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# GROUP BY start_station_name
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Average_Duration_In_Minutes                Start_Station_Name
# 0                      23.503572          ACC - West & 12th Street
# 1                      24.905572           ACC - Rio Grande & 12th
# 2                      31.528008                      Lavaca & 6th
# 3                      26.504622           Toomey Rd @ South Lamar
# 4                       9.767025              Ready for deployment
# ..                           ...                               ...
# 196                    53.163842   5th/Guadalupe @ Republic Square
# 197                   114.000000             cesar Chavez/Congress
# 198                    22.676366  23rd & San Jacinto @ DKR Stadium
# 199                    61.401109        Nash Hernandez @ RBJ South
# 200                    71.895495       Lakeshore & Pleasant Valley
#
# [201 rows x 2 columns]

# %% [markdown]
# these are the average times for a trip based on your starting point
#
# haha i did it
#
# i actually did this on my own without completely copying
#
# i am quite happy
#
# this is a great feeling

# %%
# %%bigquery --project dataviz24
# SELECT
# Count(start_station_name) as Occurrences, Start_Station_Name
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# GROUP BY start_station_name
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Occurrences                     Start_Station_Name
# 0           7290                       5th & San Marcos
# 1           6846             Lake Austin Blvd/Deep Eddy
# 2           4496                         17th/Guadalupe
# 3          11432               Barton Springs/Riverside
# 4          10800  Republic Square @ Guadalupe & 4th St.
# ..           ...                                    ...
# 196            1                         Mobile Station
# 197            4             Mobile Station @ Unplugged
# 198            4                       Customer Service
# 199            4                        Marketing Event
# 200            1                                 Stolen
#
# [201 rows x 2 columns]

# %% [markdown]
# hahaha i did it again
#
# this is the number of occurrences for trips at each starting point
#
# since i was able to do this on my own without asking dr jacobs for help and i understood what it was asking and what to do, probably a 1 star difficulty

# %% [markdown]
# ## 05 SQL (3)

# %% [markdown]
# idk if this is how you want it to be formatted but the code in the book is formatted as a sentence whereas every other code is formatted like a bullet list. me personally i prefer bullet list and it would be more uniform if it was a bullet list. you should edit it to be a bullet list.

# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
# %%bigquery --project dataviz24
# SELECT *
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# Limit 5
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     trip_id       subscriber_type bike_id bike_type                start_time  \
# 0   4116203  24 Hour Walk Up Pass      24   classic 2015-03-14 15:13:11+00:00
# 1  11159957               Walk Up      52   classic 2016-07-29 05:23:08+00:00
# 2  10748199             Weekender     765   classic 2016-07-02 09:55:23+00:00
# 3  10748217             Weekender     344   classic 2016-07-02 09:56:52+00:00
# 4  11192743             Weekender      64   classic 2016-07-31 09:33:27+00:00
#
#    start_station_id                     start_station_name end_station_id  \
# 0              2550  Republic Square @ Guadalupe & 4th St.           3293
# 1              3464                             Pease Park           2569
# 2              3464                             Pease Park           2569
# 3              3464                             Pease Park           2569
# ...

# %%
# %%bigquery --project dataviz24
# SELECT
# Count(start_station_name) as Occurrences, Start_Station_Name
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# GROUP BY start_station_name
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      Occurrences                Start_Station_Name
# 0           4339          ACC - West & 12th Street
# 1           1705           ACC - Rio Grande & 12th
# 2           5909                      Lavaca & 6th
# 3           3462           Toomey Rd @ South Lamar
# 4            279              Ready for deployment
# ..           ...                               ...
# 196         1080      Lake Austin Blvd @ Deep Eddy
# 197         8970  23rd & San Jacinto @ DKR Stadium
# 198         1082        Nash Hernandez @ RBJ South
# 199         1110       Lakeshore & Pleasant Valley
# 200            2                     Eeyore's 2018
#
# [201 rows x 2 columns]

# %% [markdown]
# so this is kind of a loophole, i didnt actually use any of the new commands this chapter, this is my same data table from sql 2. i grouped the start stations by most occurring and south congress/mary is the second most occuring, therefore it is the second most popular.

# %%
# %%bigquery --project dataviz24
# SELECT
#   start_station_name, duration_minutes
# FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
# WHERE start_station_name = end_station_name AND duration_minutes>60
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                     start_station_name  duration_minutes
# 0           East 11th St. & San Marcos               219
# 1           East 11th St. & San Marcos               218
# 2           East 11th St. & San Marcos               217
# 3       East 11th St. at Victory Grill               182
# 4       East 11th St. at Victory Grill               183
# ...                                ...               ...
# 68804                       22nd/Pearl               127
# 68805  Bullock Museum @ Congress & MLK               127
# 68806                      26th/Nueces               127
# 68807          Lakeshore/Austin Hostel               127
# 68808          Lakeshore/Austin Hostel               127
#
# [68809 rows x 2 columns]

# %% [markdown]
# 68809 trips were round trip and lasted over an hour

# %% [markdown]
# probably 2 star difficulty

# %% [markdown]
# ## 06 SQL (4)

# %% [markdown]
# ## 07 HTML (1)

# %%
import requests
import pandas as pa
from bs4 import BeautifulSoup

# %%
r = requests.get('https://en.wikipedia.org/wiki/South_Park')
html_contents = r.text
html_soup = BeautifulSoup(html_contents,"lxml")

# %%
html_soup.title
# Out:
# <title>South Park - Wikipedia</title>

# %%
links = html_soup.table.find_all('a')
listOfURLS = []

for link in links:
  listOfURLS.append('https://en.wikipedia.org' + link['href'])

listOfURLS
# Out:
# ['https://en.wikipedia.org/wiki/File:South_Park.png',
#  'https://en.wikipedia.org/wiki/Stan_Marsh',
#  'https://en.wikipedia.org/wiki/Kyle_Broflovski',
#  'https://en.wikipedia.org/wiki/Kenny_McCormick',
#  'https://en.wikipedia.org/wiki/Eric_Cartman',
#  'https://en.wikipedia.org/wiki/Animated_sitcom',
#  'https://en.wikipedia.org/wiki/Black_comedy',
#  'https://en.wikipedia.org/wiki/Satire',
#  'https://en.wikipedia.org/wiki/Surreal_humor',
#  'https://en.wikipedia.org/wiki/Trey_Parker',
#  'https://en.wikipedia.org/wiki/Matt_Stone',
#  'https://en.wikipedia.org/wiki/Brian_Graden',
#  'https://en.wikipedia.org/wiki/Mary_Kay_Bergman',
#  'https://en.wikipedia.org/wiki/Isaac_Hayes',
#  'https://en.wikipedia.org/wiki/Eliza_Schneider',
#  'https://en.wikipedia.org/wiki/Mona_Marshall',
#  'https://en.wikipedia.org/wiki/April_Stewart',
#  'https://en.wikipedia.org/wiki/Adrien_Beard',
#  'https://en.wikipedia.org/wiki/Primus_(band)',
# ...

# %% [markdown]
# one star difficulty

# %% [markdown]
# ## 08 HTML (2)

# %%
import requests
import pandas as pa
from bs4 import BeautifulSoup

r = requests.get('https://en.wikipedia.org/wiki/List_of_Marvel_Cinematic_Universe_films')
html_contents = r.text
html_soup = BeautifulSoup(html_contents, "lxml")

# %%
len(html_soup.find_all('table'))
# Out:
# 35

# %%
tables = html_soup.find_all('table',class_="wikitable")
tables[0].find_all('a')
# Out:
# [<a href="/wiki/Marvel_Cinematic_Universe:_Phase_One" title="Marvel Cinematic Universe: Phase One">Phase One</a>,
#  <a href="#cite_note-DigitalSpyPhases-25">[24]</a>,
#  <a href="/wiki/Iron_Man_(2008_film)" title="Iron Man (2008 film)">Iron Man</a>,
#  <a href="/wiki/Jon_Favreau" title="Jon Favreau">Jon Favreau</a>,
#  <a href="#cite_note-April2006Variety-28">[27]</a>,
#  <a href="/wiki/Mark_Fergus_and_Hawk_Ostby" title="Mark Fergus and Hawk Ostby">Mark Fergus &amp; Hawk Ostby</a>,
#  <a href="/wiki/Art_Marcum_and_Matt_Holloway" title="Art Marcum and Matt Holloway">Art Marcum &amp; Matt Holloway</a>,
#  <a href="#cite_note-April2006Variety-28">[27]</a>,
#  <a href="#cite_note-FergusOstbyIM-29">[28]</a>,
#  <a href="/wiki/Avi_Arad" title="Avi Arad">Avi Arad</a>,
#  <a href="/wiki/Kevin_Feige" title="Kevin Feige">Kevin Feige</a>,
#  <a href="/wiki/The_Incredible_Hulk_(film)" title="The Incredible Hulk (film)">The Incredible Hulk</a>,
# ...

# %%
df = pa.read_html(str(tables))[0]
df
# Out:
#                                    Film  U.S. release date  \
#                           Phase One[24]      Phase One[24]
# 0                              Iron Man        May 2, 2008
# 1                   The Incredible Hulk      June 13, 2008
# 2                            Iron Man 2        May 7, 2010
# 3                                  Thor        May 6, 2011
# 4    Captain America: The First Avenger      July 22, 2011
# 5                          The Avengers        May 4, 2012
# 6                         Phase Two[24]      Phase Two[24]
# 7                            Iron Man 3        May 3, 2013
# 8                  Thor: The Dark World   November 8, 2013
# 9   Captain America: The Winter Soldier      April 4, 2014
# 10              Guardians of the Galaxy     August 1, 2014
# 11              Avengers: Age of Ultron        May 1, 2015
# 12                              Ant-Man      July 17, 2015
# 13                      Phase Three[24]    Phase Three[24]
# ...

# %% [markdown]
# ok so i am kind of lost here. the assignment says to fix the column names and remove rows that are not movies. they use the rows to separate the phases... am i supposed to remove those? also i dont exactly know how because the droplevel 0 was not working for some reason and i do not understand the tables the hard way at all.

# %% [markdown]
# ## 09 Data Types

# %% [markdown]
# 1) it is quantitative data. it is good because it is the age.

# %% [markdown]
# 2) no. yes. order of school.
#
# school_type = CategoricalDType(categories=['Primary', 'Secondary', 'Tertiary'], ordered=True
#
# dfClass = df.Class.astype(school_type)
#
# dfClass.dtype

# %% [markdown]
# 3) you could make married or single boolean. 1= married, 0= single.
#
# (df.Class == "marital').dtype
#
# dtype('bool')
#
# df[df.Class == 'marital'].head(10)

# %% [markdown]
# 4) i like how they have the final results. failure is kind of cruel and funny lol

# %% [markdown]
# ## 10 Strings

# %%
hbd = print('happy birthday to you, happy birthday to you, happy birthday dear camden, happy birthday to you')
# Out:
# happy birthday to you, happy birthday to you, happy birthday dear camden, happy birthday to you
