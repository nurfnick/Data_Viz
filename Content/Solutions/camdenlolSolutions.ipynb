# %% [markdown]
# <a href="https://colab.research.google.com/github/camdenlol/Data_Viz/blob/main/Content/Solutions/camdenlolSolutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Camden Wilmes

# %%
import pandas as pd

# %% [markdown]
# ## uhhh part 1

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Data_Sets/iris.csv') #you do have headers in this dataset
df
# Out:
#      SepalLength  SepalWidth  PedalLength  PedalWidth           Class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#import pandas as pd only need to load pandas once this entire document!
df.head()
# Out:
#    SepalLength  SepalWidth  PedalLength  PedalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['SepalLength', 'SepalWidth', 'PedalLength', 'PedalWidth', 'Class'], dtype='object')

# %%
dfg = df.groupby(['Species'])['Species'].count() #you dont have a column called Species!

dfg.plot(kind='bar', title='Species of Iris', ylabel='Number of Species',
         xlabel='Species', figsize=(6, 5))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-229f40884907> in <cell line: 1>()
# ----> 1 dfg = df.groupby(['Species'])['Species'].count() #you dont have a column called Species!
#       2
#       3 dfg.plot(kind='bar', title='Species of Iris', ylabel='Number of Species',
#       4          xlabel='Species', figsize=(6, 5))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
df.groupby('Class').count()
# Out:
#                  SepalLength  SepalWidth  PedalLength  PedalWidth
# Class
# Iris-setosa               50          50           50          50
# Iris-versicolor           50          50           50          50
# Iris-virginica            50          50           50          50
