# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Data_Viz/blob/main/Content/Data_Cleaning/Exam3Review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exam 3 Review

# %% [markdown]
# Utilizing the bank dataset https://github.com/nurfnick/Data_Viz/blob/main/Data_Sets/bank.csv answer the following questions.
#
# 1. What are the datatypes for each column.  Comment on the appropriateness and change any easy/obvious ones.
# 2. Using regular expresssions, remove the hyphen "-" from any job and replace it with a space.
# 3. Convert any place where pdays is -1 to NaN.
# 4. Fill the NaN in pdays with a zero.
# 5. Compute the mean and median of balance when grouped by job.
# 6. Add a column that is a datetime.  Use year of 2020.
# 7. Which day of the week (Monday, Tuesday, ect.) had the most approved loans, y = yes.
# 8. Create an indicator column that shows if the person has more than \$500 in their acocunt.
# 9. Are divorced, admin people given loans at a higher rate?
# 10. Which job is most likely to have a default on their record?
# 11. Do highly educated people have more or less cellular phones than on average?
# 12. What is the maritial status of the person with the maximum balance?
# 12. Write another question based on your knowledge of the dataset.

# %%
import pandas as pa

df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/Data_Sets/bank.csv')

df.head(20)
# Out:
#     age            job  marital  education default  balance housing loan  \
# 0    30     unemployed  married    primary      no     1787      no   no
# 1    33       services  married  secondary      no     4789     yes  yes
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
# 9    43       services  married    primary      no      -88     yes  yes
# 10   39       services  married  secondary      no     9374     yes   no
# 11   43         admin.  married  secondary      no      264     yes   no
# ...

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %% [markdown]
# Marital status can I make true/false...

# %%
df.marital.unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %% [markdown]
# I should not make this a booleen.  The last column could be booleen but lets check...

# %%
df.y.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['y'] = (df['y'] == 'yes')

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y              bool
# dtype: object

# %% [markdown]
# ##2
# Using regular expresssions, remove the hyphen "-" from any job and replace it with a space.

# %%
df['job'] = df['job'].replace('-', ' ')

# %%
df.job
# Out:
# 0          unemployed
# 1            services
# 2          management
# 3          management
# 4         blue-collar
#             ...
# 4516         services
# 4517    self-employed
# 4518       technician
# 4519      blue-collar
# 4520     entrepreneur
# Name: job, Length: 4521, dtype: object

# %% [markdown]
# ## 3
#
# Convert any place where pdays is -1 to NaN.

# %%
import numpy as np

df['pdays'] = df['pdays'].replace(-1, np.nan)

df.pdays
# Out:
# 0         NaN
# 1       339.0
# 2       330.0
# 3         NaN
# 4         NaN
#         ...
# 4516      NaN
# 4517      NaN
# 4518      NaN
# 4519    211.0
# 4520    249.0
# Name: pdays, Length: 4521, dtype: float64

# %%
df['pdays'].isna()
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 4516     True
# 4517     True
# 4518     True
# 4519    False
# 4520    False
# Name: pdays, Length: 4521, dtype: bool

# %% [markdown]
# # 4
#
# Fill the NaN in pdays with a zero.

# %%
df['pdays'] = df['pdays'].fillna(0)

# %% [markdown]
# ## 5
#
# Compute the mean and median of balance when grouped by job.

# %%
df.groupby('job')['balance'].agg(['mean','median'])
# Out:
#                       mean  median
# job
# admin.         1226.736402   430.0
# blue-collar    1085.161734   408.5
# entrepreneur   1645.125000   365.5
# housemaid      2083.803571   296.5
# management     1766.928793   577.0
# retired        2319.191304   672.5
# self-employed  1392.409836   483.0
# services       1103.956835   288.0
# student        1543.821429   422.5
# technician     1330.996094   434.5
# unemployed     1089.421875   473.5
# unknown        1501.710526   655.5

# %% [markdown]
# ## 6
# Add a column that is a datetime. Use year of 2020.

# %%
df['datetime_column'] = pa.to_datetime(df['month'] + ' ' + df['day'].astype(str) + ' 2020', format='%b %d %Y')

# %% [markdown]
# ## 7
# Which day of the week (Monday, Tuesday, ect.) had the most approved loans, y = yes.

# %%
df['day_of_week'] = df['datetime_column'].dt.dayofweek

# %%
df.groupby('day_of_week')['y'].sum()
# Out:
# day_of_week
# 0     70
# 1    107
# 2     93
# 3    105
# 4     81
# 5     36
# 6     29
# Name: y, dtype: int64

# %% [markdown]
# # 11
# Do highly educated people have more or less cellular phones than on average?

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome      y  \
# 0  cellular   19   oct        79         1    0.0         0  unknown  False
# 1  cellular   11   may       220         1  339.0         4  failure  False
# 2  cellular   16   apr       185         1  330.0         1  failure  False
# 3   unknown    3   jun       199         4    0.0         0  unknown  False
# 4   unknown    5   may       226         1    0.0         0  unknown  False
#
#   datetime_column  day_of_week
# 0      2020-10-19            0
# ...

# %%
df.education.unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %% [markdown]
# primary -> Low Ed
#
# secondary -> moderate
#
# tertiary -> highly educated
#
# unknown -> who knows...

# %%
((df['contact'] == 'cellular') & (df['education'] == 'tertiary')).sum()/((df['contact'] == 'cellular') & (df['education'] == 'tertiary')).count()
# Out:
# np.float64(0.22384428223844283)

# %%
((df['contact'] == 'cellular') & ((df['education'] == 'primary') | (df['education'] == 'secondary'))).sum()/((df['contact'] == 'cellular') & ((df['education'] == 'primary') | (df['education'] == 'secondary'))).count()
# Out:
# np.float64(0.3957089139570891)
