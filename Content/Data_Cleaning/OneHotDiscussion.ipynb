# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Data_Viz/blob/main/Content/Data_Cleaning/OneHotDiscussion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
path = kagglehub.dataset_download("jessicali9530/animal-crossing-new-horizons-nookplaza-dataset")
# Out:
# Using Colab cache for faster access to the 'animal-crossing-new-horizons-nookplaza-dataset' dataset.

# %%
import pandas as pd
df = pd.read_csv(path + "/achievements.csv")

df.head()
# Out:
#                       Name                                     Award Criteria  \
# 0     (island name) Miles!  Awarded when Nook Miles program is first unlocked
# 1  Angling for Perfection!                        Number of total fish caught
# 2     Island Ichthyologist                       Number of unique fish caught
# 3      Island Togetherness  Number of days in which you've talked to every...
# 4       You've Got the Bug                        Number of total bugs caught
#
#    #  Internal ID      Internal Name Internal Category  Num of Tiers  Tier 1  \
# 0  1           53  ImmigratetoIsland             Event             1       1
# 1  2            0          CatchFish              Fish             5      10
# 2  3            3       FillFishList              Fish             5      10
# 3  4           68   GreetAllVillager     Communication             5       1
# 4  5            1        CatchInsect            Insect             5      10
#
# ...

# %%
df["Internal Category"] = df["Internal Category"].astype("category")

# %%
df.head()
# Out:
#                       Name                                     Award Criteria  \
# 0     (island name) Miles!  Awarded when Nook Miles program is first unlocked
# 1  Angling for Perfection!                        Number of total fish caught
# 2     Island Ichthyologist                       Number of unique fish caught
# 3      Island Togetherness  Number of days in which you've talked to every...
# 4       You've Got the Bug                        Number of total bugs caught
#
#    #  Internal ID      Internal Name Internal Category  Num of Tiers  Tier 1  \
# 0  1           53  ImmigratetoIsland             Event             1       1
# 1  2            0          CatchFish              Fish             5      10
# 2  3            3       FillFishList              Fish             5      10
# 3  4           68   GreetAllVillager     Communication             5       1
# 4  5            1        CatchInsect            Insect             5      10
#
# ...

# %%
df["Internal Category"].cat.categories
# Out:
# Index(['Communication', 'DIY', 'Event', 'Fish', 'HHA', 'Insect', 'LandMaking',
#        'Money', 'MyDesign', 'Negative', 'Plant', 'Smartphone'],
#       dtype='object')

# %%
pd.get_dummies(df["Internal Category"]).astype(int).shape
# Out:
# (84, 12)

# %%
pd.get_dummies(df['Name'])
# Out:
#     (island name) Icons  (island name) Miles!  Active Island Resident  \
# 0                 False                  True                   False
# 1                 False                 False                   False
# 2                 False                 False                   False
# 3                 False                 False                   False
# 4                 False                 False                   False
# ..                  ...                   ...                     ...
# 79                False                 False                   False
# 80                False                 False                   False
# 81                False                 False                   False
# 82                False                 False                   False
# 83                False                 False                    True
#
#     Angling for Perfection!  Bell Ringer  Birthday Celebration  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
model = OneHotEncoder()

newdf = model.fit_transform(df)

# %%
newdf.shape
# Out:
# (84, 618)

# %%
print(newdf)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1764 stored elements and shape (84, 618)>
#   Coords	Values
#   (0, 1)	1.0
#   (0, 117)	1.0
#   (0, 168)	1.0
#   (0, 299)	1.0
#   (0, 386)	1.0
#   (0, 422)	1.0
#   (0, 432)	1.0
#   (0, 439)	1.0
#   (0, 448)	1.0
#   (0, 461)	1.0
#   (0, 476)	1.0
#   (0, 491)	1.0
#   (0, 508)	1.0
#   (0, 513)	1.0
#   (0, 517)	1.0
#   (0, 521)	1.0
#   (0, 525)	1.0
#   (0, 527)	1.0
#   (0, 531)	1.0
#   (0, 532)	1.0
#   (0, 565)	1.0
#   (1, 3)	1.0
#   (1, 157)	1.0
#   (1, 169)	1.0
#   (1, 252)	1.0
#   :	:
#   (82, 527)	1.0
#   (82, 531)	1.0
#   (82, 532)	1.0
#   (82, 575)	1.0
#   (83, 2)	1.0
#   (83, 158)	1.0
#   (83, 251)	1.0
#   (83, 272)	1.0
#   (83, 364)	1.0
#   (83, 422)	1.0
#   (83, 436)	1.0
#   (83, 440)	1.0
#   (83, 454)	1.0
#   (83, 468)	1.0
#   (83, 481)	1.0
#   (83, 499)	1.0
#   (83, 507)	1.0
#   (83, 513)	1.0
#   (83, 517)	1.0
#   (83, 521)	1.0
#   (83, 525)	1.0
#   (83, 527)	1.0
#   (83, 531)	1.0
#   (83, 532)	1.0
# ...
