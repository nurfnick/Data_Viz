# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Data_Viz/blob/main/Lectures/02Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jupyter Notebooks

# %% [markdown]
# ## Markdown Textboxes

# %% [markdown]
# ### Headers

# %% [markdown]
# ### $\LaTeX$

# %% [markdown]
# ### Enumerate

# %% [markdown]
# ### Tables

# %% [markdown]
# ## Python Code

# %% [markdown]
# ### Write a function

# %% [markdown]
# ### Load Packages

# %% [markdown]
# ### Data Load

# %% [markdown]
# ### Data Viz
