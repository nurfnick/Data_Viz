# %% [markdown]
# <a href="https://colab.research.google.com/github/nurfnick/Data_Viz/blob/main/19_Missing_and_Incomplete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Missing and Incomplete

# %% [markdown]
# Often datasets will be missing entries.  There are many approaches we can take to dealing with these errors and omissions.  I will examine a dataset on the characters from <ins> The Lord of The Rings</ins>

# %%
import pandas as pa

df = pa.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/lotr_characters.csv')

df.head()
# Out:
#      birth              death  gender  ...    race  realm        spouse
# 0      NaN                NaN  Female  ...     Men    NaN       Belemir
# 1  TA 2978  February 26 ,3019    Male  ...     Men    NaN           NaN
# 2      NaN        March ,3019    Male  ...    Orcs    NaN           NaN
# 3   TA 280             TA 515    Male  ...     Men  Arnor  Unnamed wife
# 4      NaN                NaN    Male  ...  Dragon    NaN           NaN
#
# [5 rows x 9 columns]

# %% [markdown]
# We see right away that there are lots of `NaN`'s.  This is an empty field in our dataset.  Some characters are mentioned but never given much more background than a name.

# %%
df.isnull().sum(axis = 0)
# Out:
# birth     207
# death     315
# gender    143
# hair      734
# height    813
# name        0
# race      140
# realm     714
# spouse    403
# dtype: int64

# %% [markdown]
# There are null values in every column except name.

# %%
df.isnull().sum(axis = 1).value_counts().sort_index()
# Out:
# 0     15
# 1     59
# 2    185
# 3    236
# 4    178
# 5     81
# 6     20
# 7      1
# 8    136
# dtype: int64

# %% [markdown]
# Here we see that there are only 15 entries with all fields and 136 that are name only (since name was never blank!)  Let's look at just those characters.

# %%
df[~df.isnull().any(axis = 1)]
# Out:
#                          birth  ...                               spouse
# 125                    SA 3209  ...                         Unnamed wife
# 134  YT, and perhaps firstborn  ...                         Unnamed wife
# 166                         YT  ...                              Aredhel
# 186                    TA 2990  ...  Lothíriel after the War of the Ring
# 194                     FA 532  ...                            Celebrían
# 204                    SA 3119  ...                         Unnamed wife
# 530                         YT  ...                            Galadriel
# 551     Possibly pre First Age  ...                     Most likely none
# 579                       3019  ...                                 None
# 620                    TA 2925  ...                         Unnamed wife
# 686                    YT 1362  ...                             Celeborn
# 692                    YT 1169  ...                             Nerdanel
# 795                  First Age  ...                         Unnamed wife
# 802                    YT 1050  ...                               Melian
# 873              March 1 ,2931  ...                                Arwen
#
# [15 rows x 9 columns]

# %% [markdown]
# Of course we could ask for just the ones with 8 null values.

# %%
df[df.isnull().sum(axis = 1) == 8].name
# Out:
# 8                          Angrim
# 14                      Angelimar
# 17      Linda (Baggins) Proudfoot
# 18                 Bodo Proudfoot
# 40     Tanta (Hornblower) Baggins
#                   ...
# 886                        Andvír
# 891                        Amlach
# 904                         Aghan
# 905                       Agathor
# 907                      Aerandir
# Name: name, Length: 136, dtype: object

# %% [markdown]
# I only included the names since the rest of the dataset was null!

# %% [markdown]
# Of course we can use this method to include only entries that have 4 or less null entries.

# %%
df[df.isnull().sum(axis = 1) <= 4]
# Out:
#                                   birth  ...                                 spouse
# 1                               TA 2978  ...                                    NaN
# 3                                TA 280  ...                           Unnamed wife
# 5                               SA 2709  ...                           Unnamed wife
# 7                                    YT  ...                               Eldalótë
# 9                               SA 3219  ...                           Unnamed wife
# ..                                  ...  ...                                    ...
# 903                             TA 2827  ...                           Unnamed wife
# 906                      Mid ,First Age  ...                                 Brodda
# 908  YT during the ,Noontide of Valinor  ...  Loved ,Andreth but remained unmarried
# 909                             TA 2917  ...                           Unnamed wife
# 910                     Before ,TA 1944  ...                                    NaN
#
# [673 rows x 9 columns]

# %% [markdown]
# Maybe we only want the characters whose *realm* has been included.  We'll negate the `isnull()` command.

# %%
df[~df.realm.isnull()]
# Out:
#                                                  birth  ...        spouse
# 3                                               TA 280  ...  Unnamed wife
# 5                                              SA 2709  ...  Unnamed wife
# 9                                              SA 3219  ...  Unnamed wife
# 10                                             SA 3118  ...    Tar-Míriel
# 11                                             SA 2876  ...  Unnamed wife
# ..                                                 ...  ...           ...
# 890                                             TA 726  ...  Unnamed wife
# 892  Sometime during ,Years of the Trees, or the ,F...  ...  Unnamed wife
# 898                                                NaN  ...  Tar-Meneldur
# 900                                            TA 2544  ...  Unnamed wife
# 901                                            TA 1330  ...  Unnamed wife
#
# [197 rows x 9 columns]
